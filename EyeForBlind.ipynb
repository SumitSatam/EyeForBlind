# %% [markdown]
# # Eye For Blind
# This notebook will be used to prepare the capstone project 'Eye for Blind'
#
# Submitted By - Sumit S. Satam

# %%
#Import all the required libraries

import collections
import cv2
#import glob
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import random
import re
import tensorflow as tf
import time

#from glob import glob
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tqdm import tqdm

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Let's read the dataset

# %% [markdown]
# ## Data understanding
# 1.Import the dataset and read image & captions into two seperate variables
#
# 2.Visualise both the images & text present in the dataset
#
# 3.Create word-to-index and index-to-word mappings.
#
# 4.Create a dataframe which summarizes the image, path & captions as a dataframe
#
# 5.Visualise the top 30 occuring words in the captions
#
# 6.Create a list which contains all the captions & path

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls "/content/drive/My Drive/ImageCaptioning"
# Out:
# captions.txt  Images

# %%
#Import the dataset and read the image into a seperate variable

#import glob

#all_images = glob.glob('/content/drive/My Drive/ImageCaptioning/Images/*.jpg')
#print("The total images present in the dataset: {}".format(len(all_images)))

import glob 
images='/content/drive/My Drive/ImageCaptioning/Images/'

all_images = glob.glob(images + '/*.jpg',recursive=True)
print("The total images present in the dataset: {}".format(len(all_images)))
# Out:
# The total images present in the dataset: 8091

# %%
#Visualise both the images & text present in the dataset
all_images
# Out:
# ['/content/drive/My Drive/ImageCaptioning/Images/2064792226_97e41d8167.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1253275679_e955fb7304.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2990977776_1ec51c9281.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2447284966_d6bbdb4b6e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2656039837_f46b29af92.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1287064529_aa4e4f3c31.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/345284642_77dded0907.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2850719435_221f15e951.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2502782508_2c8211cd6b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2261550615_b6c25d987b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3623302162_099f983d58.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2420546021_4a59790da6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3647446816_bd4383c828.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3319338707_892ae2a660.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3712923460_1b20ebb131.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/95734036_bef6d1a871.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3550255426_4ab03c0d6e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3544669026_1b5c0e6316.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3115174046_9e96b9ce47.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1469358746_2a879abaf3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2823075967_be4c350e9e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3030223792_02b6f2be99.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3050264832_4215f2b398.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/281754914_bc8119a0ed.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/390986651_c801db91a0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2735558076_0d7bbc18fc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1351764581_4d4fb1b40f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3201427741_3033f5b625.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241347300_7c84ecf764.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2466495935_623b144183.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3595992258_6f192e6ae7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2056377805_e9a9b3bcf0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/366548880_3d3e914746.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3015863181_92ff43f4d8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2825668136_107223182c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2250870111_8402d2319d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/386656845_4e77c3e3da.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2702506716_17a7fb3ba4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/532914728_c5d8d56b0b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1142283988_6b227c5231.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/415118186_64defc96f3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3280644151_3d89cb1e0e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1402843760_d30f1dbf0f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1042020065_fb3d3ba5ba.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2090997177_76d482b158.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2533076864_d799996433.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/511282305_dbab4bf4be.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2203615439_3c7cdc39dc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/272940778_a184dbea42.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2298946012_22de913532.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3619381206_5bc8b406f9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3397259310_1ed1a346b5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2208310655_a3d83080c5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3249062399_0dafe5e4f5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2186367337_0ce9ce2104.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3477778668_81ff0a68e0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3331900249_5872e90b25.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2598012140_832863fcb9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2220612655_030413b787.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3221815947_76c95b50b7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/427936315_0b8f7b8d23.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3227111573_c82f7d68b1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3250593457_9049a73b61.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/191592626_477ef5e026.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2950637275_98f1e30cca.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2629445284_83390e83af.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3503471307_464a8f588c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3498417123_3eae6bbde6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2461990494_c5ece064cc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2591603141_33d6397e0a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/472860064_a96a228796.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3307978046_92fef4dfa9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2789648482_1df61f224a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/236095031_5cb17dc54a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/247619370_a01fb21dd3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/247097023_e656d5854d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2479652566_8f9fac8af5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3539817989_5353062a39.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/223299137_b0e81ac145.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2869765795_21a398cb24.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3065560742_f6e266ccd9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3726168984_1fa2c8965b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/180094434_b0f244832d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1324816249_86600a6759.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/414568315_5adcfc23c0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2616508003_fa5ca5780d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2238019823_79318d1f11.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3354075558_3b67eaa502.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2938316391_97382d14aa.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1473618073_7db56a5237.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2615623392_ab2b9759ae.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1810651611_35aae644fb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3111208043_dbe8e87fa1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3500829879_a643818d84.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3420278866_1d17c12713.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3197917064_e679a44b8e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3171451305_f87b9e09ee.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1119463452_69d4eecd08.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3604928725_58147c87cd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1332722096_1e3de8ae70.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/742073622_1206be8f7f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2199083344_3aa77f4879.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/543102698_38e7e38bbc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2073756099_7e02c0110c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2129430111_338a94f8fb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2589241160_3832440850.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2708176152_1634cb754d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3697379772_40d831392b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2976350388_3984e3193d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3679405397_bb130ea3c2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2525232298_cf42d415ab.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1446933195_8fe9725d62.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3503623999_bbd5dcfb18.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2428959030_bdffc2812e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/430964917_022995afb6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/143688205_630813a466.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2502354602_f4d6dcf42d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2754271176_4a2cda8c15.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3760400645_3ba51d27f9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3328247381_a9f7fb4898.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3544233095_4bca71df1d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3677927146_1696f0b075.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3275065565_9e2a640fbc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241346352_c5a0ea43c6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3041384194_04316bd416.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1143882946_1898d2eeb9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/358114269_96fdb5f7c3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3649802021_8a689bc153.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/872512911_ca383b40e4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2561341745_2d77d3ff7d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/528498076_43f0ef36b5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2883907436_82bf4a36b8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3538527033_df13112d51.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2410040397_1a161a1146.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3272541970_ac0f1de274.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2471974379_a4a4d2b389.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/326334188_8850b7bfd4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3649387275_75295baa28.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2709359730_13bca100af.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2279945145_8815c59217.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2524084967_a5e011b73d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3568605391_54ec367d88.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3399312265_9c74378692.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3609026563_9c66f2dc41.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2598979962_c01811cfca.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2679926555_b11cf45595.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2549968784_39bfbe44f9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3636796219_9916c0465a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2405978603_6221b0c2e7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/177302997_5b2d770a0a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3004287781_c041c09c16.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3566225740_375fc15dde.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/93922153_8d831f7f01.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3604383863_5e387cb8e6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/173020287_230bfc4ffc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2358554995_54ed3baa83.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3187395715_f2940c2b72.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2095435987_1b7591d214.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3532412342_e0a004b404.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/418796494_bdb441de42.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2632366677_43dee456a5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2956895529_ec6275060e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3676788491_01e9bc5f15.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3527524436_a54aca78a9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241345427_ece0d186c2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3332248667_617606714b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/401476986_73918145a3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3417143124_6feb8290cc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3462396164_ba9849c14b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/504385521_6e668691a3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3500505549_d848209837.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2088910854_c6f8d4f5f9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2331510788_986809bbb4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/95783195_e1ba3f57ca.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3051998298_38da5746fa.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3713922357_e0a013fb97.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/640409060_6af18fdd54.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2545192257_142fe9e2de.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2934837034_a8ca5b1f50.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/427167162_2c99779444.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2955673642_4279b32097.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3583321426_f373c52161.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3346614841_698f9aa486.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2217328285_b1d55c17ca.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/294549892_babb130543.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3222055946_45f7293bb2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2527163162_d0fb802992.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3372251830_baa3665928.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2324979199_4193ef7537.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/392976422_c8d0514bc3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2826030193_4278ccb833.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3149919755_f9272b10b3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3556792157_d09d42bef7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2148013097_6a4f495bc5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2021613437_d99731f986.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/409327234_7b29eecb4e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3322443827_a04a94bb91.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/397451339_76a84bd310.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/300274198_eefd8e057e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3382105769_b1a4e4c60d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/469029994_349e138606.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/566921157_07c18a41e2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2930622766_fa8f84deb1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3349258288_5300c40430.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2718049631_e7aa74cb9b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3640407952_bb38fb9d55.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3203453897_6317aac6ff.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/510531976_90bbee22a2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1211015912_9f3ee3a995.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3540598210_972f0ff573.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2417341107_97dbab9c5e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2189995738_352607a63b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3441104823_33cdae5a56.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/421730441_6b2267fd31.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3591094476_b61acd63d6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2680990587_eee6bd04fb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/429851331_b248ca01cd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/436013859_793d870b6f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3697675767_97796334e4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1352398363_9cc8ffcce9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/254901702_67ada9867c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3472485022_5d03e9852d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2346401538_f5e8da66fc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3504479370_ff2d89a043.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3003691049_f4363c2d5c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2410562803_56ec09f41c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3558370311_5734a15890.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/49553964_cee950f3ba.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2932740428_b15384f389.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/472535997_0dbf42b9f3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3350785999_462f333c44.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/393284934_d38e1cd6fe.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3582914739_bef2828a06.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3445296377_1e5082b44b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2939475047_84585ea45c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/539751252_2bd88c456b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3009383694_e045c6169e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3266406566_d64e57e65a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1984936420_3f3102132b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3670907052_c827593564.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/181777261_84c48b31cb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3302804312_0272091cd5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2810412010_f8b3bc1207.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2562347802_c049a2ba88.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2687539673_d54a8dc613.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2540757246_5a849fbdcb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/247617035_9f2e821534.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/537758332_8beb9cf522.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3293751640_d81a6f3a0c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3137061312_eb5fdcf3fd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3111502208_71e2a414f5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2294516804_11e255807a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3217291172_10ef70af88.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2899501488_90d5da5474.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3052038928_9f53aa2084.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3216085740_699c2ce1ae.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3561543598_3c1b572f9b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3673878924_506c9d767b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3422394336_e465f60b7c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3446191973_1db572ed8a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2642688531_8fb68b2147.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2922512807_d382528a93.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3069786374_804e1123ac.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2247192427_5e106f24a9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3017373346_3a34c3fe9d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3381161854_af8b05243c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/733964952_69f011a6c4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/363617160_6cb0c723be.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2256138896_3e24b0b28d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/370442541_60d93ecd13.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/661755629_602ea4cf09.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1806580620_a8fe0fb9f8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2396100671_3a9d67f03d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1921398767_771743bf4e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/576093768_e78f91c176.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3175434849_859f09fe07.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3226254560_2f8ac147ea.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2689491604_d8760f57b4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1174629344_a2e1a2bdbf.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3449114979_6cdc3e8da8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2084103826_ffd76b1e3e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/792362827_5ab5281b99.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3673484638_dce87295fe.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3419634480_c390f62a6e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2659183350_730951f740.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3549997413_01388dece0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/566794036_60f7acdf35.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3705430840_e108de78bf.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3006095077_1992b677f8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3186527735_6e9fe2cf88.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3446347599_0ecc49a9d5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3172280520_e7655fb596.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/390987167_2d5905b459.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/587604325_af5d6df679.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/694496803_f2a05869cf.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1449370354_380c4123c9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3098714492_19939e3b19.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1396703063_e8c3687afe.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3019667009_20db160195.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/101654506_8eb26cfb60.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2937461473_11bbace28c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/535529555_583d89b7f2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2288530008_4ebcee2174.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2101808682_0d66ef4a08.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2741380826_cfe0ddf0a9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/506412121_67ecc7ec05.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/191003284_1025b0fb7d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/664341930_bd5c8b60ea.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/532131603_c82d454c8a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2465691083_894fc48af6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3596959859_a7cb1e194b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/649596742_5ba84ce946.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/460478198_83039f2593.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3638459638_ec74e3ff89.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2890075175_4bd32b201a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3561314880_ea9a7e245f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2502007071_82a8c639cf.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/207930963_af3a2f1784.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2998024845_1529c11694.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241345533_99c731403a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3494105596_f05cb0d56f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1321723162_9d4c78b8af.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2962977152_9d6958fdd5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1659396176_ced00a549f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2505056124_1276e8dbcb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3515451715_ac5ac04efa.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/154871781_ae77696b77.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/206087108_d4557d38ee.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2449289139_08fc1092c1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1016887272_03199f49c4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2952320230_26601173be.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2290589734_b588471345.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2833582518_074bef3ed6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3638908276_b1751d30ff.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2886837407_a4510ab1ef.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3465606652_f380a38050.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3411022255_210eefc375.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/630476551_2ee7399f77.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2552438538_285a05b86c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3549011001_26cace3646.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/392467282_00bb22e201.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3449846784_278bc1ba92.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2537583012_4a358a6a8a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/309049466_1d7e7d5fc2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3667908724_65c7d112f2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/953941506_5082c9160c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/282131366_5f9a39c43c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/495341977_b27279f962.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3062173277_bfb5ef4c45.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3667157255_4e66d11dc2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/316833109_6500b526dc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2394003437_184a838aa9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2081615901_13092cac56.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2690702549_cf81da8cf6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/911527312_f81ee36b97.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2591455200_2319651f2f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2431723485_bc6b8e6418.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2086513494_dbbcb583e7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/947969010_f1ea572e89.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3313232606_4ce7e16b87.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/957682378_46c3b07bcd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2768248810_06d543c080.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3415178926_909db9400b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/127488876_f2d2a89588.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3177298173_78cea31d64.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2374179071_af22170d62.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3526897578_3cf77da99b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/369244499_752f0c1018.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1448511770_1a4a9c453b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/405051459_3b3a3ba5b3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3432550415_e7b77232de.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2073174497_18b779999c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2086534745_1e4ab80078.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3315616181_15dd137e27.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2805822564_6dee48e506.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/510510783_b2cf5d57bb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/146100443_906d87faa2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2591486448_48d5438343.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2905942129_2b4bf59bc0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3562169000_6aa7f1043d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3079073247_97e88e2eb7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/312156254_ef31dca5ed.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2893515010_4a3d9dcc67.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/342872408_04a2832a1b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2998504949_1022fec53b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3439128755_84409b8823.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3726130458_07df79e969.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2947452329_08f2d2a467.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1358892595_7a37c45788.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2914737181_0c8e052da8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3484832904_08619300d9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2474047296_fd9179d438.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2878190821_6e4e03dc5f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1296770308_3db2022f5a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3456251289_c4ae31d817.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2187222896_c206d63396.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/895502702_5170ada2ee.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2824401212_8da8ab99d6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3195147187_a073d59fa8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2127207912_9298824e66.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/350588129_6aef7b7fe2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2752809449_632cd991b3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/129599450_cab4e77343.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3284887033_e2e48f1863.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/425518464_a18b87c563.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/408627152_1feaa4b94e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2667015110_1670324a33.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2792212974_23b1ef05fa.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2259203920_6b93b721ce.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3594822096_e1144b85d6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3427301653_4ff0d6fd93.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/350529848_9569a3bcbc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3225998968_ef786d86e0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2595186208_9b16fa0ee3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2831656774_36982aafdb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2504277798_936a09c74d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3411579899_0f8ed09142.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3076052114_233f42ae5b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/287999021_998c2eeb91.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3284955091_59317073f0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2298097636_c5de0079de.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3259228898_cefd04580b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3339140382_2e49bc324a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3486538055_bcf4d3dfda.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/745563422_f4fa7d9157.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/270263570_3160f360d3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2905975229_7c37156dbe.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/386655611_1329495f97.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3606093421_eddd46c2c7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1474474514_b3eb492722.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3449718979_e987c64e2d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1287982439_6578006e22.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/254295381_d98fa049f4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/245252561_4f20f1c89e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3522025527_c10e6ebd26.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3672106148_56cfb5fc8d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2872197070_4e97c3ccfa.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2533010184_ef2fd71297.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3385593926_d3e9c21170.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2261169495_98254e2e66.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/256439287_990ac4a761.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3369354061_2bab79f91f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3365198533_539073002b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2112921744_92bf706805.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2749124446_d4432787b5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2985679744_75a7102aab.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2762301555_48a0d0aa24.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2226534154_cbcab7ba32.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2649850541_59a6c7f01c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2710416789_555180e399.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2369452202_8b0e8e25ca.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2998945968_86f236d1e8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2180480870_dcaf5ac0df.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3414734842_beb543f400.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1476002408_4256b7b2fa.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2933637854_984614e18b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3590647207_2d4ec3f52c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3173461705_b5cdeef1eb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3294209955_a1f1e2cc19.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/491405109_798222cfd0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3592968286_b63c81bcd2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3263141261_db3a4798b5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3427614912_b147d083b2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/327997381_55f90dc834.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3501936223_6122a13d27.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/848293676_98e73c52c1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3493479159_609ebe1b35.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3327563443_870a33f748.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3182405529_7692256746.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2259336826_0cb294e1f7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2620113705_a8fa89b8f6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3182121297_38c99b2769.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3054200086_657d4398e8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3401039304_424ffc7dbf.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3658016590_f761e72dc3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2087317114_cf06df5aa5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2946016853_ceca4f5a07.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/172097782_f0844ec317.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3167379087_927ff05a35.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/533979933_a95b03323b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/452363869_cad37e609f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3458379941_657182bb09.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/346253487_687150ab04.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2070831281_dc04b3e15d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2321865325_79b0954a5d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3578372039_57473f473c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3519815055_304dc8e8d6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2661567396_cbe4c2e5be.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1055623002_8195a43714.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3296226598_1c892c4351.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3242718240_3358f2d6e6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3133044777_8cc930a4ec.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2077079696_03380d218b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2205088706_d7e633e00d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2648310638_d6c576b5e4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2542415282_9240e1b5fc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2911928620_06c3fa293e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2763044275_aa498eb88b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1765164972_92dac06fa9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3320209694_db579cb607.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2371749487_d80195a2e7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1620397000_3883e3ecd3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3473320907_3884a7203b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/270724499_107481c88f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241347496_1a35fec8dc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2659606300_bea3feaf8b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3427540832_c882fded1d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2612488996_9450de0e54.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1348891916_ebd4413033.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3208188198_2b271d2a2e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2956562716_5aa3f6ef38.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3629664676_36bcefe6b7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1562478333_43d13e5427.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2694890967_7c7a89de16.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/249394748_2e4acfbbb5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3028969146_26929ae0e8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2402744031_11f9f2f2b8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3046190891_05c6ecd9b6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3608400551_d6f7965308.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/314685044_da4390728e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2196284168_76417efbec.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1271960365_e54033f883.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3556485995_9cd40269e9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3541483943_9776baee7c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3433259846_800a6079f0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2975118353_5af5a5df54.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2445783904_e6c38a3a3d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3666188047_e81e1d97a7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2126950128_74a4882658.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3090957866_f1b2b7f214.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2832033116_1677ea1e2e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3494723363_eaa6bc563b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3050650135_23f9d9d2f8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3635577874_48ebaac734.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/324208502_674488bcea.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1418266617_b32143275b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3229898555_16877f5180.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3354883962_170d19bfe4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2538477523_1da77eb11c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2753506871_dc38e7d153.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/459284240_5a4167bf92.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/171488318_fb26af58e2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1379026456_153fd8b51b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2616009069_82561da2e5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3038045802_93f2cd5fbc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/319938879_daf0857f91.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/530950375_eea665583f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3535284878_f90f10236e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3459362347_c412ef9901.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1303727828_d1052ee341.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241347460_81d5d62bf6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3613705104_46d854134e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2836808985_b26e4ca09e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3581818450_546c89ca38.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3397228832_8ce5b1c26f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3625519177_4c2bb9e7f0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1057210460_09c6f4c6c1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2839807428_efe42423f2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3231575742_31732664cf.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3587449716_3bf1552c36.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3533484468_0787830d49.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3203878596_cbb307ce3b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3422219732_3d0be52cc3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3042381160_ffe2b16808.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2238759450_6475641bdb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2745663684_650f84e1e6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3703413486_3c682732a0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3259757648_71edb4347b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3189964753_a95536ced9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3185662156_c877583c53.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3353962769_ba48691bc6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2700147489_f1664f2b61.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2301867590_98c0ecb0cb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2981702521_2459f2c1c4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2502935765_a0ae1fa7be.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1112212364_0c48235fc2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1924234308_c9ddcf206d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1445123245_c7b9db0e0c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3556571710_19cee6f5bd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3325497914_f9014d615b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3523874798_9ba2fa46e3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2265367960_7928c5642f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1418019748_51c7d59c11.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2144049642_070cf541b4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3436313241_6c73153fb6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3627011534_485f667b10.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2896180326_88785fe078.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3304712466_18cbdb85fe.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3214237686_6566b8b52f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/423066487_07757b2b49.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1714316707_8bbaa2a2ba.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2602085456_d1beebcb29.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3127888173_9a9a8ac3bd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1579206585_5ca6a24db0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3542418447_7c337360d6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2436081047_bca044c1d3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3458215674_2aa5e64643.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3208999896_dab42dc40b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/244760301_5809214866.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1334892555_1beff092c3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241345656_861aacefde.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2584957647_4f9235c150.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3647826834_dc63e21bd0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1236964638_1808784a3c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/252124738_796599e94b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3443853670_6c79fcfcb2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2805101709_1c8916f63a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/314904143_5a216a192b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2097403787_77a154f5b9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2555622234_3e531e4014.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/327621377_0bc3b7fd26.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2943079526_e9033a6556.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3184891327_8785194e3c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2587846523_b177c9a3e3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2199793371_343809ff70.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2978394277_4572967b97.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3503624011_733d745d5a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/661546153_9d30db6984.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/524698457_77ba13840a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3154641421_d1b9b8c24c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/197142902_f05ff198c2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2753531542_ace2c870b7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3099504809_565e17e49d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/47871819_db55ac4699.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/437404867_209625774d.jpg',
# ...
#  '/content/drive/My Drive/ImageCaptioning/Images/3123526484_02952e40fc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1713248047_d03721456d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3632258003_6a0a69bf3a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2738255684_0324ed062d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1093737381_b313cd49ff.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3373870185_f79163fa51.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3672944692_8d24a44fc6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3706653103_e777a825e4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/424869823_7aec015d87.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3560125106_691c292893.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3276448136_0d9f5069c5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3316725440_9ccd9b5417.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1584315962_5b0b45d02d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2181724497_dbb7fcb0a9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3259119085_21613b69df.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/434433505_966e50e17d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2693425189_47740c22ed.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1003163366_44323f5815.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3701544312_b2e4e9813d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/425706089_f138118e12.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2532294586_4cd76a837d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3677954655_df4c0845aa.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3585117340_73e96b6173.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2081679622_6f1442367d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3025513877_1a6160070d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2309860995_c2e2a0feeb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241346471_c756a8f139.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3036641436_d6594fc45f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/327415627_6313d32a64.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3247423890_163f00a2cb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3232470286_903a61ea16.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3437034427_6df5e9fbf9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/719837187_3e7bf1d472.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2533424347_cf2f84872b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/514990193_2d2422af2c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2273871383_1ddb3562ea.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2581066814_179d28f306.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2375924666_fee50f1cba.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1643915227_9f48068772.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2381102729_12fc4d4c76.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/356143774_ef3e93eede.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/978580450_e862715aba.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2978236380_fb24c43f1e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2860872588_f2c7b30e1a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2521062020_f8b983e4b2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1022975728_75515238d8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3504881781_6a842e043b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3230101918_7d81cb0fc8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/468310111_d9396abcbd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1339596997_8ac29c1841.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/691770760_48ce80a674.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/732468337_a37075225e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2443380641_7b38d18f5b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/86542183_5e312ae4d4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2709683703_5385ea9ef4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/379006645_b9a2886b51.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/437054333_5c2761b8cd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2458862292_466a920ee2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3710050559_f6f12760fe.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1355703632_5683a4b6fb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/422763475_0bc814dac6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3191027142_33e86636ca.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/72218201_e0e9c7d65b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3027009366_c8362521e8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2149968397_a7411729d1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3599124739_b7e60cf477.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/505062117_a70b4e10ab.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2662570182_350baa020f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3192266178_f9bf5d3dba.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2252403744_148fc11f68.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/508432819_3d055f395d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2433175169_da939372f2.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3591462960_86045906bd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/169490297_b6ff13632a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241345721_3f3724a7fc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3044746136_8b89da5f40.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3632572264_577703b384.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2918769188_565dd48060.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2745811124_12c4426b8b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2204695848_3d1b140212.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1204996216_71d7519d9a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/765929807_de381cc764.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3019199755_a984bc21b1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2589308405_e208b5e745.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2603033456_3584d95116.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/976392326_082dafc3c5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3136404885_f4d8f1d15a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3132619510_7dfc947d25.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/693785581_68bec8312a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3626475209_f71cdd06bd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/475313618_bdb2f72be5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1423126855_6cd2a3956c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3215117062_6e07a86352.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3520199925_ca18d0f41e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2484190118_e89363c465.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2752230113_b5dab6f0f1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3248220732_0f173fc197.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3120189281_1938460e85.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2044063458_fcc76a7636.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2662537919_18a29fca8a.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241046599_28b0ca7b9f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2695962887_a1647c567b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3612485611_12dd7742f7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1229756013_94663527d7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2678612999_893ed671f8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3623650392_7b75d4de21.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2670560883_7e7b563092.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2708744743_e231f7fcf9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3541474181_489f19fae7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/945509052_740bb19bc3.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3604391853_b4809fcb8c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3215238223_29de2b35cb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2628331789_c7f7d90e5d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3568505408_4e30def669.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3264937930_9623496b64.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2977379863_2e8d7a104e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2094323311_27d58b1513.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2921793132_ef19f1dd44.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3362871440_6c0f27c480.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/367964525_b1528ac6e4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2896640216_761a47f006.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3189002057_3ef61b803e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2863180332_372510aa49.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2556392380_ee57514233.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/502884177_25939ac000.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3405100926_e96308ce89.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3294717824_3bb7b5d1c8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3241965735_8742782a70.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3271468462_701eb88d3b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2977246776_b14be8290d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3514019869_7de4ece2a5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1536597926_c2e1bc2379.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2156131463_5b53636cf0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/365128300_6966058139.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3257103624_e76f25ff9e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3273403495_fcd09c453e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3710353645_8fbfaa4175.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/407678652_1f475acd65.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3389448506_7025e7cc12.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2546959333_23b957988f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3336808362_c17837afd8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/190965502_0b9ed331d9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/143552829_72b6ba49d4.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/174466741_329a52b2fe.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/391020801_aaaae1e42b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3081734118_6f2090215c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/300222673_573fd4044b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3286045254_696c6b15bd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2684489465_32ba1d0344.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2795287622_da187a3e86.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3271084924_4778d556cc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3016741474_72b4355198.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3025438110_40af7e6a80.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3361990489_92244a58ef.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/432496659_f01464d9fb.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3526431764_056d2c61dc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2661489896_cc3425777e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/344078103_4b23931ce5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3457210101_3533edebc8.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/566794440_f9ec673a2f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3234115903_f4dfc8fc75.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2178064851_bb39652d28.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/571130875_30051ac02d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2399114095_c3196ff456.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3713133789_f05e8daffd.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2673148534_8daf0de833.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3083016677_5782bc337c.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1244140539_da4804d828.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1213336750_2269b51397.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2664102751_d5a737a566.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/299676757_571ee47280.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2428094795_d3a8f46046.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/506882688_b37d549593.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/446138054_d40c66d5f0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/416106657_cab2a107a5.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3289893683_d4cc3ce208.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241345844_69e1c22464.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3567061016_62768dcce1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2244613488_4d1f9edb33.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/370614351_98b8a166b9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2528552898_9e49a7033f.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/185057637_e8ada37343.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2563578471_9a4e4c2ecc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/396179143_e1511336e1.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/395461421_c586b136de.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3103264875_2a8d534abc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3525403875_7f95e0cbfe.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/514222285_aa0c8d05b7.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/241347271_a39a5a0070.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3336361161_c06cdd160e.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3098336319_a7e5b061d0.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3155501473_510f9c9f6b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1542033433_5453d4c466.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/1095590286_c654f7e5a9.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2017276266_566656c59d.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2999162229_80d17099b6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2732625904_4fbb653434.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3563461991_de05537878.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3712008738_1e1fa728da.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2260560631_09093be4c6.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2612608861_92beaa3d0b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3138746531_f6b816c126.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3394070357_cb2a3243fc.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/290650302_ade636da35.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/439049388_3dcee2d30b.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/2893238950_8a027be110.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/3729525173_7f984ed776.jpg',
#  '/content/drive/My Drive/ImageCaptioning/Images/263233914_d25004e4cd.jpg',
#  ...]

# %%
from IPython.display import Image

#image names taken randomly from image folder to check.

a = Image(filename='/content/drive/My Drive/ImageCaptioning/Images/225909073_25c3c33a29.jpg')
b = Image(filename='/content/drive/My Drive/ImageCaptioning/Images/256085101_2c2617c5d0.jpg')

display(a,b)

# %%
#Import the dataset and read the text file into a seperate variable

text_file = "/content/drive/My Drive/ImageCaptioning/captions.txt"

def load_doc(filename):
    file = open(filename, 'r')
    text = file.read()
    print(text)
    file.close()
    return text

doc = load_doc(text_file)
print(doc[:300])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Create a dataframe which summarizes the image, path & captions as a dataframe
#
# Each image id has 5 captions associated with it therefore the total dataset should have 40455 samples.

# %%
img = '/content/drive/My Drive/ImageCaptioning/Images/'

def get_imgsid_captions(text):
    ids=[]
    vals=[]
    ids_paths=[]
    text=text.splitlines()[1:]
    for line in text:
        co_idx=line.index(",")
        im_id,im_cap=line[:co_idx],line[co_idx+1:]
        ids.append(im_id)
        vals.append(im_cap)
        ids_paths.append(img+im_id)
    return ids,vals,ids_paths

# %%
#all_img_id= #store all the image id here
#all_img_vector= #store all the image path here
#annotations= #store all the captions here
all_img_id,annotations,all_img_vector= get_imgsid_captions(doc)#store all the image id here

capdf = pd.DataFrame(list(zip(all_img_id, all_img_vector,annotations)),columns =['ID','Path', 'Captions']) 
    
capdf
# Out:
#                               ID  ...                                           Captions
# 0      1000268201_693b08cb0e.jpg  ...  A child in a pink dress is climbing up a set o...
# 1      1000268201_693b08cb0e.jpg  ...              A girl going into a wooden building .
# 2      1000268201_693b08cb0e.jpg  ...   A little girl climbing into a wooden playhouse .
# 3      1000268201_693b08cb0e.jpg  ...  A little girl climbing the stairs to her playh...
# 4      1000268201_693b08cb0e.jpg  ...  A little girl in a pink dress going into a woo...
# ...                          ...  ...                                                ...
# 40450   997722733_0cb5439472.jpg  ...           A man in a pink shirt climbs a rock face
# 40451   997722733_0cb5439472.jpg  ...           A man is rock climbing high in the air .
# 40452   997722733_0cb5439472.jpg  ...  A person in a red shirt climbing up a rock fac...
# 40453   997722733_0cb5439472.jpg  ...                    A rock climber in a red shirt .
# 40454   997722733_0cb5439472.jpg  ...  A rock climber practices on a rock climbing wa...
#
# [40455 rows x 3 columns]

# %%
capdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        40455 non-null  object
#  1   Path      40455 non-null  object
#  2   Captions  40455 non-null  object
# dtypes: object(3)
# memory usage: 948.3+ KB

# %%
print(capdf['Captions'])
# Out:
# 0        A child in a pink dress is climbing up a set o...
# 1                    A girl going into a wooden building .
# 2         A little girl climbing into a wooden playhouse .
# 3        A little girl climbing the stairs to her playh...
# 4        A little girl in a pink dress going into a woo...
#                                ...
# 40450             A man in a pink shirt climbs a rock face
# 40451             A man is rock climbing high in the air .
# 40452    A person in a red shirt climbing up a rock fac...
# 40453                      A rock climber in a red shirt .
# 40454    A rock climber practices on a rock climbing wa...
# Name: Captions, Length: 40455, dtype: object

# %%
def create_vocabulary(data):
  vocab = []
  for captions in data.Captions.values:
    vocab.extend(captions.split())
  print("Vocabulary Size : {}".format(len(set(vocab))))
  return vocab

# %%
#Create the vocabulary & the counter for the captions
from collections import Counter

vocabulary = create_vocabulary(capdf)#write your code here

val_count=Counter(vocabulary)
val_count
# Out:
# Vocabulary Size : 9862
# Counter({'A': 21481,
#          'child': 1477,
#          'in': 18961,
#          'a': 40271,
#          'pink': 734,
#          'dress': 347,
#          'is': 9345,
#          'climbing': 502,
#          'up': 1260,
#          'set': 108,
#          'of': 6712,
#          'stairs': 109,
#          'an': 1944,
#          'entry': 1,
#          'way': 50,
#          '.': 34212,
#          'girl': 3217,
#          'going': 149,
#          'into': 1074,
#          'wooden': 284,
#          'building': 509,
#          'little': 1625,
#          'playhouse': 6,
#          'the': 15328,
#          'to': 3173,
#          'her': 1178,
#          'cabin': 4,
#          'black': 3696,
#          'dog': 7982,
#          'and': 8850,
#          'spotted': 37,
#          'are': 3503,
#          'fighting': 132,
#          'tri-colored': 14,
#          'playing': 2008,
#          'with': 7760,
#          'each': 430,
#          'other': 771,
#          'on': 10729,
#          'road': 388,
#          'white': 3875,
#          'brown': 2475,
#          'spots': 29,
#          'staring': 57,
#          'at': 2904,
#          'street': 936,
#          'Two': 3962,
#          'dogs': 2082,
#          'different': 45,
#          'breeds': 5,
#          'looking': 738,
#          'pavement': 48,
#          'moving': 41,
#          'toward': 146,
#          'covered': 306,
#          'paint': 61,
#          'sits': 577,
#          'front': 1386,
#          'painted': 63,
#          'rainbow': 22,
#          'hands': 244,
#          'bowl': 30,
#          'sitting': 1368,
#          'large': 1191,
#          'small': 1207,
#          'grass': 1621,
#          'plays': 526,
#          'fingerpaints': 3,
#          'canvas': 6,
#          'it': 398,
#          'There': 226,
#          'pigtails': 14,
#          'painting': 42,
#          'Young': 176,
#          'outside': 790,
#          'man': 6828,
#          'lays': 56,
#          'bench': 375,
#          'while': 1957,
#          'his': 2357,
#          'by': 1248,
#          'him': 402,
#          'which': 51,
#          'also': 20,
#          'tied': 15,
#          'sleeping': 60,
#          'next': 749,
#          'shirtless': 97,
#          'lies': 43,
#          'park': 503,
#          'laying': 188,
#          'holding': 1324,
#          'leash': 131,
#          'ground': 355,
#          'orange': 732,
#          'hat': 679,
#          'starring': 8,
#          'something': 346,
#          'wears': 115,
#          'glasses': 206,
#          'gauges': 2,
#          'wearing': 3061,
#          'Blitz': 1,
#          'beer': 45,
#          'can': 39,
#          'crocheted': 1,
#          'The': 2920,
#          'pierced': 6,
#          'ears': 69,
#          'rope': 249,
#          'net': 58,
#          'red': 2660,
#          'roping': 2,
#          'climbs': 200,
#          'bridge': 139,
#          'grips': 2,
#          'onto': 211,
#          'ropes': 38,
#          'playground': 201,
#          'running': 2072,
#          'grassy': 473,
#          'garden': 54,
#          'surrounded': 178,
#          'fence': 340,
#          'through': 2031,
#          'Boston': 9,
#          'terrier': 23,
#          'Terrier': 8,
#          'lush': 8,
#          'green': 1218,
#          'runs': 925,
#          'near': 1022,
#          '"A': 1186,
#          'shakes': 37,
#          'its': 925,
#          'head': 374,
#          'shore': 170,
#          ',': 3210,
#          'ball': 1778,
#          '."': 2365,
#          'edge': 170,
#          'beach': 1044,
#          '"Dog': 8,
#          'feet': 87,
#          'stands': 869,
#          'shaking': 71,
#          'off': 744,
#          'water"': 4,
#          'White': 60,
#          'water': 2774,
#          'standing': 1786,
#          'turned': 20,
#          'one': 1007,
#          'side': 303,
#          'boy': 3442,
#          'smiles': 192,
#          'stony': 3,
#          'wall': 555,
#          'city': 317,
#          'overalls': 24,
#          'working': 23,
#          'stone': 127,
#          'young': 2431,
#          'aross': 1,
#          'walking': 1165,
#          'paved': 43,
#          'metal': 113,
#          'pole': 155,
#          'behind': 631,
#          'Smiling': 13,
#          'shirt': 1803,
#          'blue': 2257,
#          'jeans': 224,
#          'rock': 750,
#          'leaps': 204,
#          'over': 1414,
#          'log': 55,
#          'grey': 239,
#          'leaping': 137,
#          'fallen': 70,
#          'tree': 416,
#          'mottled': 2,
#          'collar': 198,
#          'jumping': 1469,
#          'jumped': 33,
#          'stump': 27,
#          'snow': 1481,
#          'field': 1276,
#          'surface': 65,
#          'displaying': 5,
#          'pictures': 66,
#          'skier': 173,
#          'skis': 81,
#          'past': 148,
#          'another': 953,
#          'paintings': 5,
#          'person': 1414,
#          'framed': 7,
#          'looks': 511,
#          'trees': 260,
#          'Man': 410,
#          'artwork': 4,
#          'for': 949,
#          'sale': 7,
#          'collage': 2,
#          'cliff': 195,
#          'group': 1172,
#          'people': 2442,
#          'belays': 1,
#          'Seven': 12,
#          'climbers': 27,
#          'ascending': 8,
#          'face': 482,
#          'whilst': 152,
#          'Several': 188,
#          'row': 33,
#          'watches': 275,
#          'holds': 471,
#          'line': 147,
#          'chases': 99,
#          'from': 920,
#          'sprinkler': 53,
#          'lawn': 117,
#          'hose': 45,
#          'Large': 42,
#          'away': 169,
#          'prepares': 50,
#          'catch': 368,
#          'thrown': 45,
#          'object': 155,
#          'nearby': 153,
#          'cars': 63,
#          'about': 151,
#          'yellow': 1207,
#          'mouth': 986,
#          'toy': 580,
#          'ready': 125,
#          'flying': 173,
#          'air': 1057,
#          'after': 184,
#          'get': 107,
#          'jumps': 978,
#          'towards': 247,
#          'trying': 163,
#          'midair': 210,
#          'woman': 3227,
#          'waters': 29,
#          'big': 272,
#          'lake': 332,
#          'lone': 80,
#          'duck': 36,
#          'swimming': 446,
#          'several': 113,
#          'around': 647,
#          'watching': 250,
#          'waves': 141,
#          'hand': 342,
#          '"Two': 403,
#          'facing': 55,
#          'skyline': 15,
#          'couple': 239,
#          'infant': 14,
#          'being': 338,
#          'held': 66,
#          'male': 111,
#          'pond': 96,
#          'stroller': 28,
#          'sit': 360,
#          'baby': 403,
#          'their': 693,
#          'newborn': 8,
#          'under': 246,
#          'care': 3,
#          'along': 527,
#          'body': 190,
#          'Couple': 8,
#          'outdoors': 174,
#          'surf': 78,
#          'lab': 22,
#          'tags': 7,
#          'frolicks': 2,
#          'splashes': 71,
#          'This': 96,
#          'splashing': 129,
#          'drilling': 5,
#          'hole': 37,
#          'ice': 220,
#          'frozen': 26,
#          'men': 1035,
#          'fishing': 106,
#          'play': 746,
#          'making': 154,
#          'turn': 70,
#          'soft': 13,
#          'sand': 465,
#          'together': 413,
#          'tan': 385,
#          'sandy': 110,
#          'uses': 27,
#          'picks': 12,
#          'crampons': 1,
#          'scale': 1,
#          'climber': 121,
#          'jacket': 678,
#          'pants': 259,
#          'scaling': 20,
#          'An': 455,
#          'waterfall': 85,
#          'two': 1262,
#          'Climber': 3,
#          'carries': 128,
#          'as': 865,
#          'he': 205,
#          'walks': 552,
#          'carrying': 434,
#          'has': 562,
#          'item': 20,
#          'wet': 169,
#          'kayak': 88,
#          'life': 86,
#          'jackets': 68,
#          'rowing': 35,
#          'canoe': 72,
#          'gentle': 1,
#          'ride': 253,
#          'courtyard': 28,
#          'catching': 109,
#          'Black': 129,
#          'snaps': 1,
#          'lunges': 6,
#          'Chocolate': 2,
#          'Lab': 2,
#          'too': 8,
#          'late': 3,
#          'captures': 1,
#          'driveway': 15,
#          'stick': 467,
#          'kneeling': 34,
#          'goalie': 43,
#          'hockey': 182,
#          'guarding': 9,
#          'goal': 82,
#          'kid': 171,
#          'rink': 30,
#          'right': 93,
#          '"Hockey': 1,
#          'crouches': 30,
#          'modern': 5,
#          'art': 39,
#          'structure': 77,
#          'glass': 61,
#          'reads': 46,
#          'newspaper': 38,
#          'sculpture': 22,
#          'office': 12,
#          'statue': 63,
#          'backpack': 158,
#          'buildings': 71,
#          'reading': 96,
#          'tent': 82,
#          'enter': 8,
#          'setting': 81,
#          'hut': 12,
#          'iced': 3,
#          'tarp': 8,
#          'snowy': 420,
#          'three': 298,
#          'Three': 968,
#          'hill': 444,
#          'sky': 146,
#          'them': 260,
#          'stand': 518,
#          'kneels': 26,
#          'skyscraper': 6,
#          'very': 162,
#          'tall': 144,
#          'Behind': 1,
#          'distance': 108,
#          'camera': 687,
#          'bites': 31,
#          'hard': 16,
#          'treat': 16,
#          'biting': 83,
#          'baked': 2,
#          'good': 7,
#          'putting': 35,
#          'both': 81,
#          'eats': 52,
#          'food': 92,
#          'table': 258,
#          'eating': 144,
#          'pizza': 4,
#          'tin': 1,
#          'dish': 11,
#          'People': 414,
#          'mountainside': 26,
#          'check': 6,
#          'out': 757,
#          'view': 80,
#          'hilltop': 2,
#          'overlooking': 104,
#          'valley': 23,
#          'hang': 30,
#          'top': 485,
#          'overlook': 6,
#          'rest': 24,
#          'ledge': 77,
#          'above': 226,
#          'moutains': 1,
#          'down': 1823,
#          'many': 89,
#          'inflatable': 73,
#          'boats': 39,
#          'kayakers': 8,
#          'railing': 112,
#          'rafts': 6,
#          'below': 55,
#          'crowd': 519,
#          'jersey': 114,
#          'pose': 216,
#          'some': 547,
#          'multiracial': 1,
#          'posing': 291,
#          'picture': 416,
#          '"Asian': 4,
#          'blond': 169,
#          'background': 592,
#          'Guy': 15,
#          'striped': 217,
#          'guy': 195,
#          'takeout': 1,
#          'television': 9,
#          'floor': 153,
#          'fast': 51,
#          'meal': 13,
#          'Someone': 86,
#          'TV': 8,
#          'teens': 5,
#          'Crowd': 11,
#          'rail': 102,
#          'crowded': 76,
#          'takes': 169,
#          'jump': 401,
#          'skateboard': 431,
#          'performing': 196,
#          'trick': 384,
#          'leans': 57,
#          'skateboarder': 290,
#          'doing': 434,
#          'board': 139,
#          'platform': 48,
#          'skateboarders': 9,
#          'paddling': 48,
#          'river': 235,
#          'seen': 40,
#          'kayaking': 29,
#          'paddles': 34,
#          'boat': 274,
#          'paddle': 40,
#          'shallow': 130,
#          'girls': 807,
#          'ocean': 460,
#          'four': 132,
#          'children': 1005,
#          'pajamas': 18,
#          'have': 74,
#          'pillow': 15,
#          'fight': 77,
#          'kids': 292,
#          'pillow-fight': 1,
#          'bed': 156,
#          'Children': 143,
#          'having': 48,
#          'Four': 332,
#          'constructions': 1,
#          'workers': 17,
#          'beam': 20,
#          'taking': 204,
#          'break': 33,
#          'construction': 31,
#          'I-beam': 1,
#          'take': 80,
#          'seat': 50,
#          'steel': 4,
#          'boys': 634,
#          'puddle': 93,
#          'balloon': 44,
#          'mud': 114,
#          'sunny': 66,
#          'day': 136,
#          'appears': 36,
#          'wait': 43,
#          'hailing': 1,
#          'taxi': 4,
#          'signaling': 1,
#          'traffic': 47,
#          'blonde': 186,
#          'hair': 413,
#          'tube': 61,
#          'waving': 52,
#          'arm': 148,
#          'oncoming': 2,
#          'brochure': 2,
#          'train': 108,
#          'rides': 458,
#          'magizine': 1,
#          'book': 77,
#          'pamphlet': 1,
#          'Child': 58,
#          'rocky': 244,
#          'run': 366,
#          'across': 476,
#          'stones': 9,
#          'area': 398,
#          'descends': 11,
#          'end': 52,
#          'high': 282,
#          'diving': 73,
#          'pool': 690,
#          'dive': 11,
#          'window': 136,
#          'overshirt': 1,
#          'tank': 76,
#          'chrome': 1,
#          'door': 61,
#          'puts': 34,
#          'elevator': 7,
#          'light-colored': 5,
#          'Light': 5,
#          'swim': 97,
#          'shorts': 376,
#          'trunks': 95,
#          'arms': 247,
#          'outstretched': 38,
#          'hiker': 75,
#          'bluff': 5,
#          'mountains': 204,
#          'ski': 95,
#          "'s": 400,
#          'landscape': 45,
#          'snow-covered': 49,
#          'mountain': 543,
#          'beautiful': 48,
#          'pauses': 10,
#          'mountaintop': 25,
#          'attempting': 57,
#          'purple': 312,
#          'low': 66,
#          'cut': 27,
#          'yard': 201,
#          'Frisbee': 337,
#          'parking': 72,
#          'lot': 108,
#          'middle': 153,
#          'during': 169,
#          'heavy': 25,
#          'mat': 22,
#          'between': 125,
#          'SUV': 14,
#          'pickup': 4,
#          'open': 190,
#          'busy': 97,
#          'terrain': 34,
#          'woolly': 1,
#          'Doberman': 6,
#          'One': 193,
#          'chasing': 184,
#          'catches': 123,
#          'tennis': 424,
#          ',"': 22,
#          'multicolor': 11,
#          'balloons': 28,
#          'night': 158,
#          'hot': 27,
#          'lit': 43,
#          'lined': 36,
#          'nighttime': 12,
#          'helmet': 358,
#          'bike': 859,
#          'miniature': 5,
#          'dirt': 581,
#          'bicycle': 414,
#          'race': 372,
#          'pedals': 3,
#          'quickly': 30,
#          'BMX': 37,
#          'eight': 9,
#          'gathered': 68,
#          'dark': 242,
#          'porch': 24,
#          'darkened': 10,
#          'room': 132,
#          'throwing': 109,
#          'cleans': 2,
#          'bubbles': 89,
#          'suds': 4,
#          'wiped': 2,
#          'clean': 7,
#          'foam': 20,
#          'ramp': 319,
#          'soapy': 1,
#          'getting': 124,
#          'cleaned': 1,
#          'slides': 92,
#          'slide': 300,
#          'wading': 55,
#          'toys': 49,
#          'floating': 38,
#          'backyard': 66,
#          'sliding': 123,
#          'colorful': 217,
#          'tubes': 2,
#          'falling': 80,
#          'colored': 170,
#          'wetsuit': 81,
#          'toddler': 164,
#          'waiting': 118,
#          'come': 11,
#          'so': 16,
#          '"While': 11,
#          'droplets': 7,
#          'fly': 37,
#          'throws': 67,
#          'sticks': 62,
#          'tongue': 111,
#          'Another': 2,
#          'make': 58,
#          'faces': 74,
#          'smiling': 448,
#          'sticking': 53,
#          'look': 257,
#          'silly': 17,
#          'horse': 229,
#          'sweatshirt': 78,
#          'fire': 109,
#          'barrel': 22,
#          'lead': 17,
#          'horses': 89,
#          'contained': 1,
#          'bulldog': 9,
#          'sheep': 55,
#          'boxer': 18,
#          'pushing': 64,
#          'anouther': 1,
#          'skinny': 18,
#          'smaller': 67,
#          'int': 6,
#          'various': 15,
#          'sizes': 4,
#          'lady': 207,
#          'no': 84,
#          'dock': 93,
#          'deck': 39,
#          'closeup': 50,
#          'that': 396,
#          'paws': 30,
#          'lying': 99,
#          'resting': 44,
#          'tiled': 9,
#          'eyes': 92,
#          'rests': 23,
#          'patio': 21,
#          'bricks': 5,
#          'artificial': 10,
#          'safety': 32,
#          'harness': 82,
#          'indoor': 43,
#          '"The': 169,
#          'rocks': 255,
#          'Woman': 158,
#          'ring': 68,
#          'jumphouse': 1,
#          'teenage': 71,
#          'seating': 7,
#          'inflated': 5,
#          'family': 79,
#          'tractor': 9,
#          'Polaris': 3,
#          'vehicle': 79,
#          'played': 19,
#          'wheeler': 12,
#          'riding': 906,
#          'ATV': 39,
#          'costume': 131,
#          'left': 89,
#          'sequined': 4,
#          'feather': 12,
#          'sidewalk': 375,
#          'salmon': 2,
#          'bikini': 66,
#          ';': 32,
#          'outfit': 159,
#          'drinking': 100,
#          'pop': 7,
#          'approached': 2,
#          'flamboyant': 3,
#          'dressed': 563,
#          'feathered': 8,
#          'headress': 1,
#          'Skiiers': 9,
#          'forest': 160,
#          'skiing': 112,
#          'wooded': 101,
#          'cross-country': 18,
#          'skiers': 31,
#          'woodland': 21,
#          'trail': 146,
#          'woods': 210,
#          'hikers': 33,
#          'pathway': 12,
#          'light': 157,
#          'path': 324,
#          'happily': 26,
#          'Energetic': 1,
#          'mother': 40,
#          'boardwalk': 24,
#          'sea': 30,
#          'Some': 76,
#          'pier': 33,
#          'evening': 9,
#          'pony': 12,
#          'wintertime': 2,
#          'atop': 37,
#          'draft': 3,
#          'n': 2,
#          'daft': 1,
#          'pull': 32,
#          'cart': 85,
#          'golden': 101,
#          'sleigh': 4,
#          'driven': 10,
#          'coat': 268,
#          'pulling': 110,
#          'carriage': 19,
#          'sled': 113,
#          'steered': 2,
#          'sheer': 16,
#          'using': 64,
#          'flat': 14,
#          'rappels': 2,
#          'steep': 62,
#          'incline': 11,
#          'vest': 98,
#          'inside': 172,
#          'dome': 3,
#          'Shaft': 1,
#          'cave': 21,
#          'shows': 32,
#          'spelunkers': 1,
#          'Spelunkers': 1,
#          'cavern': 1,
#          'bathed': 1,
#          'sunlight': 11,
#          'backpackers': 2,
#          'lay': 20,
#          'dry': 79,
#          'camp': 6,
#          'gear': 115,
#          'chalk': 17,
#          'portrait': 6,
#          'stream': 111,
#          'drawing': 13,
#          'barn-like': 1,
#          'elaborate': 11,
#          'illustration': 2,
#          'deep': 82,
#          'pile': 76,
#          'fountain': 181,
#          'fountains': 14,
#          'sprayed': 25,
#          'Corgi': 2,
#          'tunnel': 67,
#          'course': 135,
#          'Dog': 144,
#          'obstacle': 125,
#          'obedience': 3,
#          'swimsuit': 61,
#          'Little': 129,
#          'handrail': 33,
#          'bathing': 119,
#          'suit': 244,
#          'spray': 36,
#          'soaked': 12,
#          'jet': 22,
#          'shower': 20,
#          'gets': 107,
#          'underwater': 53,
#          'red-headed': 4,
#          'swims': 104,
#          'gun': 41,
#          'foot': 44,
#          'aims': 5,
#          'fireplace': 11,
#          'new': 7,
#          'light-up': 2,
#          'Boy': 119,
#          'pointed': 13,
#          'alone': 35,
#          'jagged': 7,
#          'snowmobile': 13,
#          'mid': 8,
#          'snowmobiler': 1,
#          'flies': 104,
#          'rider': 183,
#          'or': 87,
#          'machine': 31,
#          'pine': 23,
#          'Rider': 2,
#          'rural': 45,
#          'snowmobiles': 4,
#          'helmets': 39,
#          'goggles': 73,
#          'snowmobiling': 2,
#          'helmeted': 14,
#          'drive': 16,
#          'ATVs': 3,
#          'heads': 49,
#          'wheel': 60,
#          'wheelers': 3,
#          'empty': 49,
#          'all': 137,
#          '!': 9,
#          'gin': 1,
#          'four-wheeler': 5,
#          'airborne': 73,
#          'quad': 6,
#          'harvested': 2,
#          'cornfield': 1,
#          's': 2,
#          'happy': 20,
#          'OD': 1,
#          'playfully': 32,
#          'soccer': 570,
#          'tucked': 1,
#          't-shirt': 145,
#          'Small': 64,
#          'artist': 14,
#          'paints': 12,
#          'clouds': 32,
#          'braids': 6,
#          'colors': 22,
#          'paper': 79,
#          'cyclist': 65,
#          'curved': 4,
#          'aerodynamic': 2,
#          'sharp': 20,
#          'curve': 24,
#          'pedaling': 3,
#          '"Man': 26,
#          'cows': 12,
#          'graze': 2,
#          'biker': 162,
#          'fetch': 31,
#          'pounces': 8,
#          'cine': 1,
#          'old': 161,
#          'fashioned': 6,
#          'video': 39,
#          'steadies': 2,
#          'aim': 4,
#          'Girl': 103,
#          'rosy': 1,
#          'cheeks': 6,
#          'lips': 17,
#          'Border': 2,
#          'Collie': 7,
#          'audience': 38,
#          'dug': 3,
#          'watch': 239,
#          'agile': 1,
#          'onlookers': 48,
#          'closely': 5,
#          'smooth': 6,
#          'stacking': 1,
#          'Toddler': 3,
#          'against': 201,
#          'backdrop': 9,
#          'shoes': 91,
#          'rappeling': 1,
#          'headlamp': 2,
#          'attached': 53,
#          'snakeskin': 1,
#          'Person': 122,
#          'sprays': 11,
#          'frog': 2,
#          'public': 48,
#          'wood': 72,
#          'barrior': 1,
#          'animal': 96,
#          'bird': 191,
#          'seeds': 6,
#          'someone': 72,
#          'sunflower': 1,
#          'clinging': 5,
#          'finger': 36,
#          'wades': 12,
#          'guided': 3,
#          'laughs': 33,
#          'playful': 7,
#          'this': 23,
#          'beige': 54,
#          'torwards': 1,
#          'outdoor': 136,
#          'handstand': 48,
#          'does': 232,
#          'sheets': 5,
#          'upside': 96,
#          'snowboard': 88,
#          'surfboard': 146,
#          'bikes': 86,
#          'traveling': 16,
#          'worn': 5,
#          'motorcycles': 27,
#          'motorbikes': 7,
#          'follow': 14,
#          'dirt-bikes': 1,
#          'off-road': 10,
#          'garment': 2,
#          'flag': 98,
#          'crescent': 1,
#          'moon': 5,
#          'star': 9,
#          'gown': 9,
#          'Muslim': 3,
#          'helps': 28,
#          'wave': 317,
#          'Baby': 14,
#          'half': 31,
#          'naked': 46,
#          'chair': 132,
#          'older': 205,
#          'back': 378,
#          'relaxes': 12,
#          'adobe': 1,
#          'where': 34,
#          'bicycles': 54,
#          'propped': 4,
#          'cap': 195,
#          'close': 43,
#          'parked': 41,
#          'relaxing': 15,
#          'folding': 11,
#          '"Topless': 2,
#          'slippers': 2,
#          'navy': 14,
#          'reclining': 2,
#          'hauling': 1,
#          'Both': 2,
#          'retrieve': 9,
#          'mouths': 40,
#          'tug': 30,
#          'chew': 16,
#          '"There': 43,
#          'haired': 145,
#          'bottled': 2,
#          'drink': 106,
#          'tilted': 4,
#          'spiked': 4,
#          'party': 56,
#          'streets': 28,
#          'they': 116,
#          'women': 612,
#          'parade': 68,
#          'neck-deep': 1,
#          'vegetation': 4,
#          'filled': 44,
#          '"Brown': 14,
#          'bushes': 37,
#          'creating': 8,
#          'splash': 44,
#          'seaweed': 11,
#          'lav': 1,
#          'swimmers': 10,
#          'kelp': 1,
#          'foreground': 40,
#          'sandals': 21,
#          'short': 69,
#          'sleeved': 14,
#          'pinstripe': 2,
#          'snows': 4,
#          'furry': 59,
#          'attempts': 56,
#          'itself': 20,
#          'self': 5,
#          'backpacks': 32,
#          'placed': 9,
#          'cardboard': 27,
#          'bus': 81,
#          'station': 34,
#          'bouncing': 29,
#          'folded': 9,
#          'beds': 3,
#          'bedroom': 5,
#          'snowboarder': 220,
#          'slope': 76,
#          'boarders': 1,
#          'Snowboarders': 3,
#          'slopes': 7,
#          'clothing': 130,
#          'store': 111,
#          ...})

# %%
#Visualise the top 30 occuring words in the captions

#write your code here
most_occur = val_count.most_common(30)

print(most_occur)
# Out:
# [('a', 40271), ('.', 34212), ('A', 21481), ('in', 18961), ('the', 15328), ('on', 10729), ('is', 9345), ('and', 8850), ('dog', 7982), ('with', 7760), ('man', 6828), ('of', 6712), ('Two', 3962), ('white', 3875), ('black', 3696), ('are', 3503), ('boy', 3442), ('woman', 3227), ('girl', 3217), (',', 3210), ('to', 3173), ('wearing', 3061), ('The', 2920), ('at', 2904), ('water', 2774), ('red', 2660), ('brown', 2475), ('people', 2442), ('young', 2431), ('."', 2365)]

# %%
import seaborn as sns

# %%
def get_top_words_based_on_cnt(words_dict,n_words):
    n_words+=1
    keys=list(words_dict.keys())
    values=list(words_dict.values())
    sorted_values=sorted(values,reverse=True)[:n_words]
    sorted_keys=[]
    for i in sorted_values:
        if sorted_values.count(i)==1:
            sorted_keys.append(keys[values.index(i)])
        elif sorted_values.count(i)==2:
            f_idx=values.index(i)
            s_idx=values[f_idx+1:].index(i)
            s_idx+=f_idx+1
            a,b=keys[f_idx],keys[s_idx]
            if a not in sorted_keys and b not in sorted_keys:
                sorted_keys.append(a)
                sorted_keys.append(b)
    plt.figure(figsize=(10,6))
    sns.barplot(x=sorted_keys,y=sorted_values)
    plt.xticks(rotation=60)
    plt.show()
    #write your code here
get_top_words_based_on_cnt(val_count,30)

# %%
#Create a list which contains all the captions
annotations=list(capdf['Captions'])

#add the <start> & <end> token to all those captions as well
annotations = capdf.Captions.apply(lambda s:"<start>"+" "+s+" "+"<end>")

#Create a list which contains all the path to the images
all_img_path=list(capdf['Path'])
print("Total captions present in the dataset: "+ str(len(annotations)))
print("Total images present in the dataset: " + str(len(all_img_path)))
# Out:
# Total captions present in the dataset: 40455
# Total images present in the dataset: 40455

# %% [markdown]
# ## Pre-Processing the captions
# 1.Create the tokenized vectors by tokenizing the captions fore ex :split them using spaces & other filters.
# This gives us a vocabulary of all of the unique words in the data. Keep the total vocaublary to top 5,000 words for saving memory.
#
# 2.Replace all other words with the unknown token "UNK" .
#
# 3.Create word-to-index and index-to-word mappings.
#
# 4.Pad all sequences to be the same length as the longest one.

# %%
# create the tokenizer

#your code here

topT = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=topT+1,oov_token="<unk>",filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(annotations)
train_seqs = tokenizer.texts_to_sequences(annotations)

tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
annotations[:10]
# Out:
# 0    <start> A child in a pink dress is climbing up...
# 1    <start> A girl going into a wooden building . ...
# 2    <start> A little girl climbing into a wooden p...
# 3    <start> A little girl climbing the stairs to h...
# 4    <start> A little girl in a pink dress going in...
# 5    <start> A black dog and a spotted dog are figh...
# 6    <start> A black dog and a tri-colored dog play...
# 7    <start> A black dog and a white dog with brown...
# 8    <start> Two dogs of different breeds looking a...
# 9    <start> Two dogs on pavement moving toward eac...
# Name: Captions, dtype: object

# %%
train_seqs[:10]
# Out:
# [[3, 2, 44, 5, 2, 91, 173, 8, 120, 52, 2, 394, 13, 395, 5, 29, 1, 671, 4],
#  [3, 2, 20, 317, 65, 2, 197, 118, 4],
#  [3, 2, 41, 20, 120, 65, 2, 197, 2438, 4],
#  [3, 2, 41, 20, 120, 6, 395, 21, 61, 2438, 4],
#  [3, 2, 41, 20, 5, 2, 91, 173, 317, 65, 2, 197, 2982, 4],
#  [3, 2, 16, 10, 9, 2, 844, 10, 18, 344, 4],
#  [3, 2, 16, 10, 9, 2, 1576, 236, 10, 35, 11, 138, 83, 7, 6, 152, 4],
#  [3, 2, 16, 10, 9, 2, 15, 10, 11, 28, 1002, 18, 641, 23, 138, 83, 5, 6, 73, 4],
#  [3, 14, 32, 13, 742, 2654, 90, 23, 138, 83, 7, 6, 152, 4],
#  [3, 14, 32, 7, 728, 806, 322, 138, 83, 4]]

# %%
tokenizer.oov_token
# Out:
# '<unk>'

# %%
tokenizer.index_word
# Out:
# {1: '<unk>',
#  2: 'a',
#  3: '<start>',
#  4: '<end>',
#  5: 'in',
#  6: 'the',
#  7: 'on',
#  8: 'is',
#  9: 'and',
#  10: 'dog',
#  11: 'with',
#  12: 'man',
#  13: 'of',
#  14: 'two',
#  15: 'white',
#  16: 'black',
#  17: 'boy',
#  18: 'are',
#  19: 'woman',
#  20: 'girl',
#  21: 'to',
#  22: 'wearing',
#  23: 'at',
#  24: 'people',
#  25: 'water',
#  26: 'red',
#  27: 'young',
#  28: 'brown',
#  29: 'an',
#  30: 'his',
#  31: 'blue',
#  32: 'dogs',
#  33: 'running',
#  34: 'through',
#  35: 'playing',
#  36: 'while',
#  37: 'shirt',
#  38: 'down',
#  39: 'standing',
#  40: 'ball',
#  41: 'little',
#  42: 'grass',
#  43: 'snow',
#  44: 'child',
#  45: 'person',
#  46: 'jumping',
#  47: 'over',
#  48: 'three',
#  49: 'front',
#  50: 'sitting',
#  51: 'holding',
#  52: 'up',
#  53: 'field',
#  54: 'small',
#  55: 'by',
#  56: 'large',
#  57: 'green',
#  58: 'one',
#  59: 'group',
#  60: 'yellow',
#  61: 'her',
#  62: 'walking',
#  63: 'children',
#  64: 'men',
#  65: 'into',
#  66: 'air',
#  67: 'beach',
#  68: 'near',
#  69: 'mouth',
#  70: 'jumps',
#  71: 'another',
#  72: 'for',
#  73: 'street',
#  74: 'runs',
#  75: 'its',
#  76: 'from',
#  77: 'riding',
#  78: 'stands',
#  79: 'as',
#  80: 'bike',
#  81: 'girls',
#  82: 'outside',
#  83: 'other',
#  84: 'off',
#  85: 'out',
#  86: 'rock',
#  87: 'next',
#  88: 'play',
#  89: 'orange',
#  90: 'looking',
#  91: 'pink',
#  92: 'player',
#  93: 'camera',
#  94: 'their',
#  95: 'pool',
#  96: 'hat',
#  97: 'jacket',
#  98: 'boys',
#  99: 'women',
#  100: 'around',
#  101: 'behind',
#  102: 'some',
#  103: 'background',
#  104: 'dirt',
#  105: 'toy',
#  106: 'soccer',
#  107: 'sits',
#  108: 'dressed',
#  109: 'has',
#  110: 'wall',
#  111: 'mountain',
#  112: 'walks',
#  113: 'crowd',
#  114: 'along',
#  115: 'plays',
#  116: 'stand',
#  117: 'looks',
#  118: 'building',
#  119: 'park',
#  120: 'climbing',
#  121: 'four',
#  122: 'top',
#  123: 'face',
#  124: 'football',
#  125: 'across',
#  126: 'grassy',
#  127: 'holds',
#  128: 'sand',
#  129: 'stick',
#  130: 'smiling',
#  131: 'ocean',
#  132: 'rides',
#  133: 'swimming',
#  134: 'hill',
#  135: 'skateboard',
#  136: 'carrying',
#  137: 'doing',
#  138: 'each',
#  139: 'tennis',
#  140: 'car',
#  141: 'tree',
#  142: 'snowy',
#  143: 'baby',
#  144: 'picture',
#  145: 'bicycle',
#  146: 'hair',
#  147: 'together',
#  148: 'jump',
#  149: 'him',
#  150: 'it',
#  151: "'s",
#  152: 'road',
#  153: 'area',
#  154: 'that',
#  155: 'basketball',
#  156: 'tan',
#  157: 'back',
#  158: 'trick',
#  159: 'race',
#  160: 'swing',
#  161: 'head',
#  162: 'shorts',
#  163: 'bench',
#  164: 'sidewalk',
#  165: 'covered',
#  166: 'run',
#  167: 'catch',
#  168: 'game',
#  169: 'sit',
#  170: 'helmet',
#  171: 'ground',
#  172: 'hand',
#  173: 'dress',
#  174: 'something',
#  175: 'fence',
#  176: 'kids',
#  177: 'being',
#  178: 'frisbee',
#  179: 'lake',
#  180: 'path',
#  181: 'city',
#  182: 'ramp',
#  183: 'walk',
#  184: 'wave',
#  185: 'skateboarder',
#  186: 'several',
#  187: 'long',
#  188: 'purple',
#  189: 'side',
#  190: 'there',
#  191: 'slide',
#  192: 'baseball',
#  193: 'high',
#  194: 'posing',
#  195: 'track',
#  196: 'players',
#  197: 'wooden',
#  198: 'big',
#  199: 'sunglasses',
#  200: 'watches',
#  201: 'boat',
#  202: 'uniform',
#  203: 'dark',
#  204: 'coat',
#  205: 'trees',
#  206: 'look',
#  207: 'them',
#  208: 'pants',
#  209: 'table',
#  210: 'rocks',
#  211: 'ride',
#  212: 'rope',
#  213: 'watching',
#  214: 'motorcycle',
#  215: 'grey',
#  216: 'suit',
#  217: 'couple',
#  218: 'towards',
#  219: 'arms',
#  220: 'beside',
#  221: 'hands',
#  222: 'under',
#  223: 'rocky',
#  224: 'sign',
#  225: 'watch',
#  226: 'snowboarder',
#  227: 'river',
#  228: 'horse',
#  229: 'does',
#  230: 'above',
#  231: 'racing',
#  232: 'older',
#  233: 'jeans',
#  234: 'lady',
#  235: 'ice',
#  236: 'colored',
#  237: 'striped',
#  238: 'colorful',
#  239: 'pose',
#  240: 'who',
#  241: 'onto',
#  242: 'woods',
#  243: 'midair',
#  244: 'guy',
#  245: 'he',
#  246: 'glasses',
#  247: 'taking',
#  248: 'leaps',
#  249: 'mountains',
#  250: 'haired',
#  251: 'asian',
#  252: 'climbs',
#  253: 'playground',
#  254: 'blonde',
#  255: 'yard',
#  256: 'against',
#  257: 'collar',
#  258: 'performing',
#  259: 'cliff',
#  260: 'hockey',
#  261: 'cap',
#  262: 'blond',
#  263: 'bird',
#  264: 'smiles',
#  265: 'body',
#  266: 'open',
#  267: 'laying',
#  268: 'surfer',
#  269: 'team',
#  270: 'many',
#  271: 'rider',
#  272: 'after',
#  273: 'chasing',
#  274: 'kid',
#  275: 'wet',
#  276: 'fountain',
#  277: 'skier',
#  278: 'surrounded',
#  279: 'outdoors',
#  280: 'flying',
#  281: 'during',
#  282: 'inside',
#  283: 'old',
#  284: 'brick',
#  285: 'biker',
#  286: 'others',
#  287: 'shore',
#  288: 'edge',
#  289: 'away',
#  290: 'takes',
#  291: 'light',
#  292: 'toddler',
#  293: 'guitar',
#  294: 't',
#  295: 'hanging',
#  296: 'trying',
#  297: 'very',
#  298: 'middle',
#  299: 'someone',
#  300: 'forest',
#  301: 'five',
#  302: 'backpack',
#  303: 'night',
#  304: 'outfit',
#  305: 'gray',
#  306: 'pole',
#  307: 'bed',
#  308: 'talking',
#  309: 'object',
#  310: 'steps',
#  311: 'making',
#  312: 'floor',
#  313: 'nearby',
#  314: 'whilst',
#  315: 'line',
#  316: 'about',
#  317: 'going',
#  318: 'flowers',
#  319: 'past',
#  320: 'arm',
#  321: 'sky',
#  322: 'toward',
#  323: 'tall',
#  324: 'trail',
#  325: 'surfboard',
#  326: 'swinging',
#  327: 'eating',
#  328: 'dancing',
#  329: 'board',
#  330: 'waves',
#  331: 'this',
#  332: 'poses',
#  333: 'bridge',
#  334: 'leaves',
#  335: 'all',
#  336: 'day',
#  337: 'leaping',
#  338: 'window',
#  339: 'outdoor',
#  340: 'bag',
#  341: 'course',
#  342: 'clothes',
#  343: 'legs',
#  344: 'fighting',
#  345: 'chair',
#  346: 'room',
#  347: 'costume',
#  348: 'house',
#  349: 'leash',
#  350: 'plastic',
#  351: 'shallow',
#  352: 'clothing',
#  353: 'splashing',
#  354: 'stone',
#  355: 'carries',
#  356: 'shirts',
#  357: 'ready',
#  358: 'climber',
#  359: 'between',
#  360: 'obstacle',
#  361: 'getting',
#  362: 'bright',
#  363: 'catches',
#  364: 'sliding',
#  365: 'adult',
#  366: 'they',
#  367: 'swings',
#  368: 'skateboarding',
#  369: 'bathing',
#  370: 'sweater',
#  371: 'concrete',
#  372: 'waiting',
#  373: 'sled',
#  374: 'trampoline',
#  375: 'lawn',
#  376: 'gear',
#  377: 'winter',
#  378: 'wears',
#  379: 'metal',
#  380: 'mud',
#  381: 'skiing',
#  382: 'uniforms',
#  383: 'male',
#  384: 'jersey',
#  385: 'railing',
#  386: 'number',
#  387: 'sandy',
#  388: 'tongue',
#  389: 'fire',
#  390: 'stream',
#  391: 'store',
#  392: 'golden',
#  393: 'pulling',
#  394: 'set',
#  395: 'stairs',
#  396: 'catching',
#  397: 'distance',
#  398: 'throwing',
#  399: 'upside',
#  400: 'sun',
#  401: 'train',
#  402: 'lot',
#  403: 'drink',
#  404: 'bar',
#  405: 'get',
#  406: 'fishing',
#  407: 'gets',
#  408: 'tries',
#  409: 'adults',
#  410: 'smile',
#  411: 'shirtless',
#  412: 'overlooking',
#  413: 'like',
#  414: 'swims',
#  415: 'flies',
#  416: 'rail',
#  417: 'ski',
#  418: 'female',
#  419: 'couch',
#  420: 'wooded',
#  421: 'tricks',
#  422: 'makes',
#  423: 'busy',
#  424: 'drinking',
#  425: 'puppy',
#  426: 'chases',
#  427: 'lying',
#  428: 'animal',
#  429: 'tire',
#  430: 'vest',
#  431: 'flag',
#  432: 'surfing',
#  433: 'swim',
#  434: 'performs',
#  435: 'american',
#  436: 'cellphone',
#  437: 'pond',
#  438: 'reading',
#  439: 'laughing',
#  440: 'right',
#  441: 'trunks',
#  442: 'leaning',
#  443: 'flip',
#  444: 'shopping',
#  445: 'huge',
#  446: 'food',
#  447: 'puddle',
#  448: 'dock',
#  449: 'she',
#  450: 'slides',
#  451: 'horses',
#  452: 'eyes',
#  453: 'hats',
#  454: 'photo',
#  455: 'bat',
#  456: 'shoes',
#  457: 'nose',
#  458: 'sunset',
#  459: 'left',
#  460: 'kayak',
#  461: 'bubbles',
#  462: 'cart',
#  463: 'truck',
#  464: 'climb',
#  465: 'coming',
#  466: 'stunt',
#  467: 'deep',
#  468: 'snowboard',
#  469: 'hold',
#  470: 'scarf',
#  471: 'feet',
#  472: 'life',
#  473: 'no',
#  474: 'or',
#  475: 'bikes',
#  476: 'family',
#  477: 'umbrella',
#  478: 'waterfall',
#  479: 'goal',
#  480: 'view',
#  481: 'elderly',
#  482: 'equipment',
#  483: 'restaurant',
#  484: 'tent',
#  485: 'skating',
#  486: 'hurdle',
#  487: 'greyhound',
#  488: 'biting',
#  489: 'both',
#  490: 'skis',
#  491: 'lone',
#  492: 'setting',
#  493: 'harness',
#  494: 'take',
#  495: 'falling',
#  496: 'wetsuit',
#  497: 'bus',
#  498: 'mask',
#  499: 'muddy',
#  500: 'hiker',
#  501: 'flags',
#  502: 'vehicle',
#  503: 'dry',
#  504: 'paper',
#  505: 'skirt',
#  506: 'bags',
#  507: 'guys',
#  508: 'court',
#  509: 'surf',
#  510: 'crowded',
#  511: 'fight',
#  512: 'sweatshirt',
#  513: 'dresses',
#  514: 'structure',
#  515: 'ledge',
#  516: 'book',
#  517: 'tank',
#  518: 'bmx',
#  519: 'six',
#  520: 'be',
#  521: 'pile',
#  522: 'slope',
#  523: 'go',
#  524: 'cigarette',
#  525: 'german',
#  526: 'raft',
#  527: 'airborne',
#  528: 'short',
#  529: 'driving',
#  530: 'skate',
#  531: 'kick',
#  532: 'have',
#  533: 'diving',
#  534: 'faces',
#  535: 'cross',
#  536: 'cement',
#  537: 'inflatable',
#  538: 'goggles',
#  539: 'wood',
#  540: 'costumes',
#  541: 'graffiti',
#  542: 'goes',
#  543: 'canoe',
#  544: 'parking',
#  545: 'teenage',
#  546: 'cyclist',
#  547: 'subway',
#  548: 'dance',
#  549: 'kicking',
#  550: 'bottle',
#  551: 'shaking',
#  552: 'splashes',
#  553: 'buildings',
#  554: 'fallen',
#  555: 'turn',
#  556: 'parade',
#  557: 'hit',
#  558: 'shepherd',
#  559: 'ears',
#  560: 'ring',
#  561: 'sports',
#  562: 'jackets',
#  563: 'gathered',
#  564: 'blanket',
#  565: 'pictures',
#  566: 'low',
#  567: 'backyard',
#  568: 'throws',
#  569: 'smaller',
#  570: 'closeup',
#  571: 'tunnel',
#  572: 'band',
#  573: 'full',
#  574: 'silver',
#  575: 'chairs',
#  576: 'microphone',
#  577: 'smoking',
#  578: 'leather',
#  579: 'held',
#  580: 'sunny',
#  581: 'bikini',
#  582: 'wheel',
#  583: 'piece',
#  584: 'boots',
#  585: 'event',
#  586: 'balls',
#  587: 'beard',
#  588: 'bull',
#  589: 'surface',
#  590: 'cars',
#  591: 'cat',
#  592: 'fluffy',
#  593: 'stage',
#  594: 'kicks',
#  595: 'painted',
#  596: 'make',
#  597: 'pushing',
#  598: 'using',
#  599: 'bicyclist',
#  600: 'hiking',
#  601: 'outfits',
#  602: 'box',
#  603: 'rugby',
#  604: 'statue',
#  605: 'stuffed',
#  606: 'pointing',
#  607: 'paint',
#  608: 'sticks',
#  609: 'steep',
#  610: 'gold',
#  611: 'bald',
#  612: 'bucket',
#  613: 'blowing',
#  614: 'glass',
#  615: 'tube',
#  616: 'door',
#  617: 'swimsuit',
#  618: 'drinks',
#  619: 'scooter',
#  620: 'suits',
#  621: 'sleeping',
#  622: 'flower',
#  623: 'throw',
#  624: 'shot',
#  625: 'volleyball',
#  626: 'cow',
#  627: 'furry',
#  628: 'hugging',
#  629: 'corner',
#  630: 'wrestling',
#  631: 'net',
#  632: 'crossing',
#  633: 'wrestle',
#  634: 'same',
#  635: 'hangs',
#  636: 'hind',
#  637: 'cowboy',
#  638: 'points',
#  639: 'leg',
#  640: 'motorcyclist',
#  641: 'staring',
#  642: 'leans',
#  643: 'attempting',
#  644: 'police',
#  645: 'kissing',
#  646: 'spectators',
#  647: 'lays',
#  648: 'wading',
#  649: 'sheep',
#  650: 'party',
#  651: 'attempts',
#  652: 'few',
#  653: 'teams',
#  654: 'show',
#  655: 'bunch',
#  656: 'log',
#  657: 'facing',
#  658: 'below',
#  659: 'beige',
#  660: 'bicycles',
#  661: 'close',
#  662: 'puppies',
#  663: 'cup',
#  664: 'snowboarding',
#  665: 'hoop',
#  666: 'desert',
#  667: 'garden',
#  668: 'african',
#  669: 'wide',
#  670: 'fenced',
#  671: 'way',
#  672: 'sprinkler',
#  673: 'fast',
#  674: 'beautiful',
#  675: 'sticking',
#  676: 'underwater',
#  677: 'attached',
#  678: 'fish',
#  679: 'gym',
#  680: 'softball',
#  681: 'gather',
#  682: 'competition',
#  683: 'eats',
#  684: 'waving',
#  685: 'end',
#  686: 'onlookers',
#  687: 'naked',
#  688: 'filled',
#  689: 'phone',
#  690: 'wings',
#  691: 'poles',
#  692: 'racket',
#  693: 'racetrack',
#  694: 'which',
#  695: 'dances',
#  696: 'talks',
#  697: 'rain',
#  698: 'gravel',
#  699: 'base',
#  700: 'rolling',
#  701: 'prepares',
#  702: 'seat',
#  703: 'lit',
#  704: 'empty',
#  705: 'clear',
#  706: 'motocross',
#  707: 'racer',
#  708: 'seated',
#  709: 'hula',
#  710: 'do',
#  711: 'headband',
#  712: 'signs',
#  713: 'toys',
#  714: 'heads',
#  715: 'neck',
#  716: 'wear',
#  717: 'hits',
#  718: 'ladies',
#  719: 'pushes',
#  720: 'plaid',
#  721: 'branch',
#  722: 'mohawk',
#  723: 'market',
#  724: 'downhill',
#  725: 'birds',
#  726: 'bride',
#  727: 'round',
#  728: 'pavement',
#  729: 'platform',
#  730: 'paddling',
#  731: 'having',
#  732: 'public',
#  733: 'handstand',
#  734: 'just',
#  735: 'shop',
#  736: 'traffic',
#  737: 'rough',
#  738: 'shoulder',
#  739: 'scene',
#  740: 'among',
#  741: 'skateboards',
#  742: 'different',
#  743: 'reads',
#  744: 'bearded',
#  745: 'gloves',
#  746: 'chewing',
#  747: 'school',
#  748: 'beer',
#  749: 'hose',
#  750: 'thrown',
#  751: 'landscape',
#  752: 'rural',
#  753: 'drives',
#  754: 'dirty',
#  755: 'bars',
#  756: 'barefoot',
#  757: 'tie',
#  758: 'urban',
#  759: 'kitchen',
#  760: 'teeth',
#  761: 'races',
#  762: 'cream',
#  763: 'balloon',
#  764: 'resting',
#  765: 'foot',
#  766: 'tug',
#  767: 'splash',
#  768: 'display',
#  769: 'carnival',
#  770: 'before',
#  771: 'bottom',
#  772: 'cricket',
#  773: 'painting',
#  774: 'lies',
#  775: 'paved',
#  776: 'goalie',
#  777: 'wait',
#  778: 'indoor',
#  779: 'mother',
#  780: 'plants',
#  781: 'carpet',
#  782: 'creek',
#  783: 'says',
#  784: 'waits',
#  785: 'younger',
#  786: 'rapids',
#  787: 'wedding',
#  788: 'flight',
#  789: 'smoke',
#  790: 'match',
#  791: 'opposing',
#  792: 'lined',
#  793: 'half',
#  794: 'headphones',
#  795: 'animals',
#  796: 'pipe',
#  797: 'lap',
#  798: 'fall',
#  799: 'showing',
#  800: 'block',
#  801: 'stadium',
#  802: 'skates',
#  803: 'greyhounds',
#  804: 'blows',
#  805: 'wrestler',
#  806: 'moving',
#  807: 'boats',
#  808: 'gun',
#  809: 'parked',
#  810: 'reaching',
#  811: 'onstage',
#  812: 'santa',
#  813: 'art',
#  814: 'seen',
#  815: 'paddle',
#  816: 'video',
#  817: 'where',
#  818: 'mouths',
#  819: 'foreground',
#  820: 'war',
#  821: 'talk',
#  822: 'chase',
#  823: 'bandanna',
#  824: 'third',
#  825: 'instruments',
#  826: 'singing',
#  827: 'lights',
#  828: 'runner',
#  829: 'falls',
#  830: 'can',
#  831: 'deck',
#  832: 'atv',
#  833: 'helmets',
#  834: 'pulled',
#  835: 'photograph',
#  836: 'ear',
#  837: 'motorbike',
#  838: 'wire',
#  839: 'funny',
#  840: 'matching',
#  841: 'poodle',
#  842: 'curly',
#  843: 'shooting',
#  844: 'spotted',
#  845: 'ropes',
#  846: 'newspaper',
#  847: 'outstretched',
#  848: 'floating',
#  849: 'fly',
#  850: 'audience',
#  851: 'brightly',
#  852: 'hitting',
#  853: 'fair',
#  854: 'try',
#  855: 'unicycle',
#  856: 'reaches',
#  857: 'amusement',
#  858: 'hay',
#  859: 'staircase',
#  860: 'christmas',
#  861: 'shakes',
#  862: 'duck',
#  863: 'hole',
#  864: 'atop',
#  865: 'spray',
#  866: 'bushes',
#  867: 'preparing',
#  868: 'bank',
#  869: 'alongside',
#  870: 'purse',
#  871: 'retriever',
#  872: 'pack',
#  873: 'martial',
#  874: 'shoulders',
#  875: 'wheelie',
#  876: 'raises',
#  877: 'bubble',
#  878: 'teenagers',
#  879: 'giant',
#  880: 'grinding',
#  881: 'appears',
#  882: 'terrain',
#  883: 'country',
#  884: 'skiers',
#  885: 'finger',
#  886: 'hooded',
#  887: 'stop',
#  888: 'follows',
#  889: 'formation',
#  890: 'chain',
#  891: 'roller',
#  892: 'plate',
#  893: 'pulls',
#  894: 'hoops',
#  895: 'kite',
#  896: 'digging',
#  897: 'larger',
#  898: 'surfs',
#  899: 'muzzle',
#  900: 'rowing',
#  901: 'putting',
#  902: 'hikers',
#  903: 'alone',
#  904: 'denim',
#  905: 'enjoys',
#  906: 'cold',
#  907: 'hoodie',
#  908: 'music',
#  909: 'balancing',
#  910: 'jeep',
#  911: 'covering',
#  912: 'perform',
#  913: 'muzzled',
#  914: 'rodeo',
#  915: 'row',
#  916: 'kneeling',
#  917: 'paddles',
#  918: 'puts',
#  919: 'pier',
#  920: 'station',
#  921: 'giving',
#  922: 'shaggy',
#  923: 'picnic',
#  924: 'backwards',
#  925: 'gives',
#  926: 'indoors',
#  927: 'spinning',
#  928: 'himself',
#  929: 'shadow',
#  930: 'parachute',
#  931: 'jumped',
#  932: 'hang',
#  933: 'break',
#  934: 'shows',
#  935: 'handrail',
#  936: 'laughs',
#  937: 'leap',
#  938: 'bite',
#  939: 'backs',
#  940: 'cut',
#  941: 'safety',
#  942: 'pull',
#  943: 'playfully',
#  944: 'clouds',
#  945: 'backpacks',
#  946: 'writing',
#  947: 'ladder',
#  948: 'enjoying',
#  949: 'owner',
#  950: 'competing',
#  951: 'necklace',
#  952: 'gate',
#  953: 'counter',
#  954: 'sniffing',
#  955: 'licking',
#  956: 'riders',
#  957: 'terrier',
#  958: 'seven',
#  959: 'bites',
#  960: 'construction',
#  961: 'machine',
#  962: 'fetch',
#  963: 'bikers',
#  964: 'skinned',
#  965: 'underneath',
#  966: 'jungle',
#  967: 'made',
#  968: 'cloth',
#  969: 'fur',
#  970: 'mound',
#  971: 'basket',
#  972: 'violin',
#  973: 'doorway',
#  974: 'fingers',
#  975: 'passing',
#  976: 'tackle',
#  977: 'bowl',
#  978: 'rink',
#  979: 'crouches',
#  980: 'quickly',
#  981: 'paws',
#  982: 'sea',
#  983: 'mid',
#  984: 'collie',
#  985: 'step',
#  986: 'computer',
#  987: 'camouflage',
#  988: 'these',
#  989: 'splashed',
#  990: 'hillside',
#  991: 'referee',
#  992: 'taken',
#  993: 'coats',
#  994: 'professional',
#  995: 'rollerblades',
#  996: 'decorated',
#  997: 'friend',
#  998: 'pigeons',
#  999: 'ducks',
#  1000: 'military',
#  ...}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('<start>', 40455),
#              ('a', 62992),
#              ('child', 1545),
#              ('in', 18986),
#              ('pink', 739),
#              ('dress', 348),
#              ('is', 9345),
#              ('climbing', 507),
#              ('up', 1302),
#              ('set', 109),
#              ('of', 6723),
#              ('stairs', 109),
#              ('an', 2432),
#              ('entry', 1),
#              ('way', 53),
#              ('<end>', 40455),
#              ('girl', 3328),
#              ('going', 149),
#              ('into', 1074),
#              ('wooden', 284),
#              ('building', 510),
#              ('little', 1768),
#              ('playhouse', 6),
#              ('the', 18419),
#              ('to', 3176),
#              ('her', 1178),
#              ('cabin', 4),
#              ('black', 3848),
#              ('dog', 8138),
#              ('and', 8862),
#              ('spotted', 38),
#              ('are', 3504),
#              ('fighting', 133),
#              ('tri', 14),
#              ('colored', 221),
#              ('playing', 2008),
#              ('with', 7765),
#              ('each', 430),
#              ('other', 773),
#              ('on', 10745),
#              ('road', 398),
#              ('white', 3959),
#              ('brown', 2578),
#              ('spots', 29),
#              ('staring', 57),
#              ('at', 2915),
#              ('street', 944),
#              ('two', 5642),
#              ('dogs', 2125),
#              ('different', 46),
#              ('breeds', 5),
#              ('looking', 743),
#              ('pavement', 48),
#              ('moving', 41),
#              ('toward', 146),
#              ('covered', 372),
#              ('paint', 62),
#              ('sits', 577),
#              ('front', 1386),
#              ('painted', 64),
#              ('rainbow', 22),
#              ('hands', 246),
#              ('bowl', 30),
#              ('sitting', 1368),
#              ('large', 1236),
#              ('small', 1278),
#              ('grass', 1622),
#              ('plays', 526),
#              ('fingerpaints', 3),
#              ('canvas', 6),
#              ('it', 401),
#              ('there', 304),
#              ('pigtails', 14),
#              ('painting', 43),
#              ('young', 2630),
#              ('outside', 791),
#              ('man', 7274),
#              ('lays', 56),
#              ('bench', 375),
#              ('while', 1968),
#              ('his', 2357),
#              ('by', 1249),
#              ('him', 403),
#              ('which', 51),
#              ('also', 20),
#              ('tied', 15),
#              ('sleeping', 60),
#              ('next', 749),
#              ('shirtless', 104),
#              ('lies', 43),
#              ('park', 508),
#              ('laying', 189),
#              ('holding', 1324),
#              ('leash', 131),
#              ('ground', 357),
#              ('orange', 745),
#              ('hat', 682),
#              ('starring', 8),
#              ('something', 346),
#              ('wears', 115),
#              ('glasses', 206),
#              ('gauges', 2),
#              ('wearing', 3062),
#              ('blitz', 1),
#              ('beer', 45),
#              ('can', 39),
#              ('crocheted', 1),
#              ('pierced', 6),
#              ('ears', 69),
#              ('rope', 251),
#              ('net', 58),
#              ('red', 2691),
#              ('roping', 2),
#              ('climbs', 201),
#              ('bridge', 141),
#              ('grips', 2),
#              ('onto', 211),
#              ('ropes', 38),
#              ('playground', 201),
#              ('running', 2073),
#              ('grassy', 474),
#              ('garden', 54),
#              ('surrounded', 178),
#              ('fence', 340),
#              ('through', 2032),
#              ('boston', 9),
#              ('terrier', 31),
#              ('lush', 8),
#              ('green', 1234),
#              ('runs', 925),
#              ('near', 1025),
#              ('shakes', 37),
#              ('its', 925),
#              ('head', 377),
#              ('shore', 170),
#              ('ball', 1783),
#              ('edge', 170),
#              ('beach', 1046),
#              ('feet', 87),
#              ('stands', 869),
#              ('shaking', 71),
#              ('off', 766),
#              ('water', 2790),
#              ('standing', 1787),
#              ('turned', 20),
#              ('one', 1222),
#              ('side', 306),
#              ('boy', 3581),
#              ('smiles', 192),
#              ('stony', 3),
#              ('wall', 557),
#              ('city', 319),
#              ('overalls', 24),
#              ('working', 24),
#              ('stone', 128),
#              ('aross', 1),
#              ('walking', 1165),
#              ('paved', 43),
#              ('metal', 115),
#              ('pole', 157),
#              ('behind', 633),
#              ('smiling', 464),
#              ('shirt', 1962),
#              ('blue', 2279),
#              ('jeans', 225),
#              ('rock', 759),
#              ('leaps', 204),
#              ('over', 1415),
#              ('log', 55),
#              ('grey', 249),
#              ('leaping', 138),
#              ('fallen', 70),
#              ('tree', 427),
#              ('mottled', 2),
#              ('collar', 198),
#              ('jumping', 1473),
#              ('jumped', 33),
#              ('stump', 28),
#              ('snow', 1547),
#              ('field', 1283),
#              ('surface', 65),
#              ('displaying', 5),
#              ('pictures', 67),
#              ('skier', 179),
#              ('skis', 82),
#              ('past', 148),
#              ('another', 956),
#              ('paintings', 5),
#              ('person', 1542),
#              ('framed', 7),
#              ('looks', 512),
#              ('trees', 261),
#              ('artwork', 4),
#              ('for', 949),
#              ('sale', 7),
#              ('collage', 2),
#              ('cliff', 195),
#              ('group', 1218),
#              ('people', 2883),
#              ('belays', 1),
#              ('seven', 31),
#              ('climbers', 27),
#              ('ascending', 8),
#              ('face', 486),
#              ('whilst', 152),
#              ('several', 314),
#              ('row', 34),
#              ('watches', 276),
#              ('holds', 471),
#              ('line', 152),
#              ('chases', 99),
#              ('from', 920),
#              ('sprinkler', 53),
#              ('lawn', 117),
#              ('hose', 45),
#              ('away', 170),
#              ('prepares', 50),
#              ('catch', 368),
#              ('thrown', 45),
#              ('object', 155),
#              ('nearby', 153),
#              ('cars', 65),
#              ('about', 152),
#              ('yellow', 1217),
#              ('mouth', 989),
#              ('toy', 582),
#              ('ready', 125),
#              ('flying', 174),
#              ('air', 1062),
#              ('after', 184),
#              ('get', 107),
#              ('jumps', 979),
#              ('towards', 247),
#              ('trying', 163),
#              ('midair', 210),
#              ('woman', 3402),
#              ('waters', 29),
#              ('big', 280),
#              ('lake', 332),
#              ('lone', 82),
#              ('duck', 37),
#              ('swimming', 446),
#              ('around', 648),
#              ('watching', 251),
#              ('waves', 142),
#              ('hand', 349),
#              ('facing', 55),
#              ('skyline', 15),
#              ('couple', 248),
#              ('infant', 15),
#              ('being', 338),
#              ('held', 66),
#              ('male', 114),
#              ('pond', 96),
#              ('stroller', 28),
#              ('sit', 360),
#              ('baby', 419),
#              ('their', 693),
#              ('newborn', 8),
#              ('under', 246),
#              ('care', 3),
#              ('along', 527),
#              ('body', 192),
#              ('outdoors', 175),
#              ('surf', 78),
#              ('lab', 24),
#              ('tags', 7),
#              ('frolicks', 2),
#              ('splashes', 71),
#              ('this', 142),
#              ('splashing', 129),
#              ('drilling', 5),
#              ('hole', 37),
#              ('ice', 222),
#              ('frozen', 26),
#              ('men', 1121),
#              ('fishing', 107),
#              ('play', 747),
#              ('making', 154),
#              ('turn', 70),
#              ('soft', 13),
#              ('sand', 467),
#              ('together', 413),
#              ('tan', 394),
#              ('sandy', 111),
#              ('uses', 27),
#              ('picks', 12),
#              ('crampons', 1),
#              ('scale', 1),
#              ('climber', 125),
#              ('jacket', 678),
#              ('pants', 259),
#              ('scaling', 20),
#              ('waterfall', 85),
#              ('carries', 128),
#              ('as', 868),
#              ('he', 209),
#              ('walks', 552),
#              ('carrying', 434),
#              ('has', 562),
#              ('item', 20),
#              ('wet', 182),
#              ('kayak', 89),
#              ('life', 87),
#              ('jackets', 68),
#              ('rowing', 35),
#              ('canoe', 72),
#              ('gentle', 1),
#              ('ride', 255),
#              ('courtyard', 28),
#              ('catching', 109),
#              ('snaps', 1),
#              ('lunges', 6),
#              ('chocolate', 15),
#              ('too', 8),
#              ('late', 3),
#              ('captures', 1),
#              ('driveway', 15),
#              ('stick', 467),
#              ('kneeling', 34),
#              ('goalie', 43),
#              ('hockey', 195),
#              ('guarding', 9),
#              ('goal', 85),
#              ('kid', 183),
#              ('rink', 30),
#              ('right', 95),
#              ('crouches', 30),
#              ('modern', 5),
#              ('art', 40),
#              ('structure', 77),
#              ('glass', 61),
#              ('reads', 46),
#              ('newspaper', 38),
#              ('sculpture', 22),
#              ('office', 12),
#              ('statue', 63),
#              ('backpack', 159),
#              ('buildings', 71),
#              ('reading', 96),
#              ('tent', 84),
#              ('enter', 8),
#              ('setting', 82),
#              ('hut', 12),
#              ('iced', 3),
#              ('tarp', 8),
#              ('snowy', 422),
#              ('three', 1387),
#              ('hill', 445),
#              ('sky', 147),
#              ('them', 260),
#              ('stand', 519),
#              ('kneels', 26),
#              ('skyscraper', 6),
#              ('very', 163),
#              ('tall', 146),
#              ('distance', 109),
#              ('camera', 700),
#              ('bites', 31),
#              ('hard', 19),
#              ('treat', 16),
#              ('biting', 83),
#              ('baked', 2),
#              ('good', 7),
#              ('putting', 35),
#              ('both', 83),
#              ('eats', 52),
#              ('food', 93),
#              ('table', 258),
#              ('eating', 144),
#              ('pizza', 10),
#              ('tin', 1),
#              ('dish', 11),
#              ('mountainside', 26),
#              ('check', 7),
#              ('out', 763),
#              ('view', 85),
#              ('hilltop', 2),
#              ('overlooking', 104),
#              ('valley', 23),
#              ('hang', 33),
#              ('top', 488),
#              ('overlook', 6),
#              ('rest', 24),
#              ('ledge', 77),
#              ('above', 228),
#              ('moutains', 1),
#              ('down', 1843),
#              ('many', 185),
#              ('inflatable', 73),
#              ('boats', 41),
#              ('kayakers', 8),
#              ('railing', 113),
#              ('rafts', 6),
#              ('below', 55),
#              ('crowd', 531),
#              ('jersey', 114),
#              ('pose', 216),
#              ('some', 626),
#              ('multiracial', 1),
#              ('posing', 291),
#              ('picture', 419),
#              ('asian', 202),
#              ('blond', 194),
#              ('background', 595),
#              ('guy', 210),
#              ('striped', 220),
#              ('takeout', 1),
#              ('television', 9),
#              ('floor', 154),
#              ('fast', 53),
#              ('meal', 14),
#              ('someone', 161),
#              ('tv', 13),
#              ('teens', 7),
#              ('rail', 103),
#              ('crowded', 78),
#              ('takes', 170),
#              ('jump', 406),
#              ('skateboard', 435),
#              ('performing', 196),
#              ('trick', 385),
#              ('leans', 57),
#              ('skateboarder', 315),
#              ('doing', 434),
#              ('board', 143),
#              ('platform', 48),
#              ('skateboarders', 11),
#              ('paddling', 48),
#              ('river', 237),
#              ('seen', 40),
#              ('kayaking', 29),
#              ('paddles', 34),
#              ('boat', 276),
#              ('paddle', 40),
#              ('shallow', 130),
#              ('girls', 844),
#              ('ocean', 463),
#              ('four', 501),
#              ('children', 1156),
#              ('pajamas', 18),
#              ('have', 74),
#              ('pillow', 16),
#              ('fight', 78),
#              ('kids', 340),
#              ('bed', 157),
#              ('having', 48),
#              ('constructions', 1),
#              ('workers', 18),
#              ('beam', 21),
#              ('taking', 205),
#              ('break', 33),
#              ('construction', 31),
#              ('i', 17),
#              ('take', 81),
#              ('seat', 50),
#              ('steel', 4),
#              ('boys', 666),
#              ('puddle', 93),
#              ('balloon', 44),
#              ('mud', 115),
#              ('sunny', 66),
#              ('day', 139),
#              ('appears', 36),
#              ('wait', 43),
#              ('hailing', 1),
#              ('taxi', 4),
#              ('signaling', 1),
#              ('traffic', 47),
#              ('blonde', 201),
#              ('hair', 414),
#              ('tube', 61),
#              ('waving', 52),
#              ('arm', 148),
#              ('oncoming', 2),
#              ('brochure', 2),
#              ('train', 108),
#              ('rides', 458),
#              ('magizine', 1),
#              ('book', 77),
#              ('pamphlet', 1),
#              ('rocky', 245),
#              ('run', 369),
#              ('across', 476),
#              ('stones', 9),
#              ('area', 398),
#              ('descends', 11),
#              ('end', 52),
#              ('high', 293),
#              ('diving', 74),
#              ('pool', 692),
#              ('dive', 11),
#              ('window', 138),
#              ('overshirt', 1),
#              ('tank', 77),
#              ('chrome', 1),
#              ('door', 61),
#              ('puts', 34),
#              ('elevator', 7),
#              ('light', 169),
#              ('swim', 97),
#              ('shorts', 377),
#              ('trunks', 95),
#              ('arms', 247),
#              ('outstretched', 38),
#              ('hiker', 80),
#              ('bluff', 5),
#              ('mountains', 204),
#              ('ski', 103),
#              ("'s", 401),
#              ('landscape', 45),
#              ('mountain', 556),
#              ('beautiful', 53),
#              ('pauses', 10),
#              ('mountaintop', 25),
#              ('attempting', 57),
#              ('purple', 312),
#              ('low', 67),
#              ('cut', 32),
#              ('yard', 201),
#              ('frisbee', 337),
#              ('parking', 72),
#              ('lot', 108),
#              ('middle', 163),
#              ('during', 174),
#              ('heavy', 28),
#              ('mat', 22),
#              ('between', 125),
#              ('suv', 14),
#              ('pickup', 4),
#              ('open', 192),
#              ('busy', 100),
#              ('terrain', 36),
#              ('woolly', 1),
#              ('doberman', 17),
#              ('chasing', 184),
#              ('catches', 123),
#              ('tennis', 429),
#              ('multicolor', 11),
#              ('balloons', 28),
#              ('night', 159),
#              ('hot', 29),
#              ('lit', 50),
#              ('lined', 42),
#              ('nighttime', 12),
#              ('helmet', 358),
#              ('bike', 868),
#              ('miniature', 5),
#              ('dirt', 592),
#              ('bicycle', 418),
#              ('race', 382),
#              ('pedals', 3),
#              ('quickly', 30),
#              ('bmx', 77),
#              ('eight', 17),
#              ('gathered', 68),
#              ('dark', 269),
#              ('porch', 24),
#              ('darkened', 10),
#              ('room', 132),
#              ('throwing', 109),
#              ('cleans', 2),
#              ('bubbles', 89),
#              ('suds', 4),
#              ('wiped', 2),
#              ('clean', 7),
#              ('foam', 20),
#              ('ramp', 319),
#              ('soapy', 1),
#              ('getting', 124),
#              ('cleaned', 1),
#              ('slides', 92),
#              ('slide', 302),
#              ('wading', 56),
#              ('toys', 49),
#              ('floating', 38),
#              ('backyard', 67),
#              ('sliding', 123),
#              ('colorful', 218),
#              ('tubes', 2),
#              ('falling', 81),
#              ('wetsuit', 81),
#              ('toddler', 169),
#              ('waiting', 118),
#              ('come', 11),
#              ('so', 17),
#              ('droplets', 7),
#              ('fly', 38),
#              ('throws', 67),
#              ('sticks', 62),
#              ('tongue', 111),
#              ('make', 64),
#              ('faces', 74),
#              ('sticking', 53),
#              ('look', 261),
#              ('silly', 17),
#              ('horse', 233),
#              ('sweatshirt', 78),
#              ('fire', 111),
#              ('barrel', 22),
#              ('lead', 17),
#              ('horses', 92),
#              ('contained', 1),
#              ('bulldog', 9),
#              ('sheep', 56),
#              ('boxer', 18),
#              ('pushing', 64),
#              ('anouther', 1),
#              ('skinny', 18),
#              ('smaller', 67),
#              ('int', 6),
#              ('various', 19),
#              ('sizes', 4),
#              ('lady', 223),
#              ('no', 87),
#              ('dock', 93),
#              ('deck', 39),
#              ('closeup', 67),
#              ('that', 397),
#              ('paws', 30),
#              ('lying', 99),
#              ('resting', 44),
#              ('tiled', 9),
#              ('eyes', 92),
#              ('rests', 23),
#              ('patio', 21),
#              ('bricks', 5),
#              ('artificial', 10),
#              ('safety', 32),
#              ('harness', 82),
#              ('indoor', 43),
#              ('rocks', 257),
#              ('ring', 69),
#              ('jumphouse', 1),
#              ('teenage', 72),
#              ('seating', 7),
#              ('inflated', 5),
#              ('family', 86),
#              ('tractor', 10),
#              ('polaris', 3),
#              ('vehicle', 79),
#              ('played', 19),
#              ('wheeler', 21),
#              ('riding', 907),
#              ('atv', 39),
#              ('costume', 132),
#              ('left', 90),
#              ('sequined', 4),
#              ('feather', 12),
#              ('sidewalk', 375),
#              ('salmon', 2),
#              ('bikini', 66),
#              ('outfit', 159),
#              ('drinking', 100),
#              ('pop', 7),
#              ('approached', 2),
#              ('flamboyant', 3),
#              ('dressed', 570),
#              ('feathered', 8),
#              ('headress', 1),
#              ('skiiers', 9),
#              ('forest', 160),
#              ('skiing', 115),
#              ('wooded', 101),
#              ('cross', 74),
#              ('country', 36),
#              ('skiers', 36),
#              ('woodland', 21),
#              ('trail', 146),
#              ('woods', 211),
#              ('hikers', 35),
#              ('pathway', 12),
#              ('path', 325),
#              ('happily', 26),
#              ('energetic', 1),
#              ('mother', 43),
#              ('boardwalk', 24),
#              ('sea', 30),
#              ('pier', 34),
#              ('evening', 9),
#              ('pony', 13),
#              ('wintertime', 2),
#              ('atop', 37),
#              ('draft', 3),
#              ('n', 2),
#              ('daft', 1),
#              ('pull', 32),
#              ('cart', 89),
#              ('golden', 110),
#              ('sleigh', 4),
#              ('driven', 10),
#              ('coat', 269),
#              ('pulling', 110),
#              ('carriage', 19),
#              ('sled', 118),
#              ('steered', 2),
#              ('sheer', 16),
#              ('using', 64),
#              ('flat', 14),
#              ('rappels', 2),
#              ('steep', 62),
#              ('incline', 11),
#              ('vest', 98),
#              ('inside', 174),
#              ('dome', 3),
#              ('shaft', 2),
#              ('cave', 21),
#              ('shows', 33),
#              ('spelunkers', 2),
#              ('cavern', 1),
#              ('bathed', 1),
#              ('sunlight', 11),
#              ('backpackers', 2),
#              ('lay', 24),
#              ('dry', 79),
#              ('camp', 6),
#              ('gear', 117),
#              ('chalk', 17),
#              ('portrait', 7),
#              ('stream', 111),
#              ('drawing', 13),
#              ('barn', 13),
#              ('like', 104),
#              ('elaborate', 11),
#              ('illustration', 2),
#              ('deep', 88),
#              ('pile', 76),
#              ('fountain', 181),
#              ('fountains', 14),
#              ('sprayed', 25),
#              ('corgi', 7),
#              ('tunnel', 67),
#              ('course', 135),
#              ('obstacle', 125),
#              ('obedience', 3),
#              ('swimsuit', 61),
#              ('handrail', 33),
#              ('bathing', 119),
#              ('suit', 249),
#              ('spray', 37),
#              ('soaked', 12),
#              ('jet', 23),
#              ('shower', 20),
#              ('gets', 107),
#              ('underwater', 53),
#              ('headed', 16),
#              ('swims', 104),
#              ('gun', 41),
#              ('foot', 44),
#              ('aims', 5),
#              ('fireplace', 11),
#              ('new', 17),
#              ('pointed', 13),
#              ('alone', 35),
#              ('jagged', 7),
#              ('snowmobile', 13),
#              ('mid', 30),
#              ('snowmobiler', 2),
#              ('flies', 104),
#              ('rider', 185),
#              ('or', 87),
#              ('machine', 31),
#              ('pine', 23),
#              ('rural', 45),
#              ('snowmobiles', 4),
#              ('helmets', 39),
#              ('goggles', 73),
#              ('snowmobiling', 2),
#              ('helmeted', 15),
#              ('drive', 16),
#              ('atvs', 3),
#              ('heads', 49),
#              ('wheel', 66),
#              ('wheelers', 3),
#              ('empty', 50),
#              ('all', 140),
#              ('gin', 1),
#              ('airborne', 75),
#              ('quad', 6),
#              ('harvested', 2),
#              ('cornfield', 1),
#              ('s', 3),
#              ('happy', 20),
#              ('od', 1),
#              ('playfully', 32),
#              ('soccer', 580),
#              ('tucked', 1),
#              ('t', 166),
#              ('artist', 14),
#              ('paints', 12),
#              ('clouds', 32),
#              ('braids', 6),
#              ('colors', 22),
#              ('paper', 79),
#              ('cyclist', 72),
#              ('curved', 4),
#              ('aerodynamic', 2),
#              ('sharp', 21),
#              ('curve', 24),
#              ('pedaling', 3),
#              ('cows', 13),
#              ('graze', 2),
#              ('biker', 171),
#              ('fetch', 31),
#              ('pounces', 8),
#              ('cine', 1),
#              ('old', 174),
#              ('fashioned', 8),
#              ('video', 40),
#              ('steadies', 2),
#              ('aim', 4),
#              ('rosy', 1),
#              ('cheeks', 6),
#              ('lips', 17),
#              ('border', 9),
#              ('collie', 30),
#              ('audience', 38),
#              ('dug', 3),
#              ('watch', 240),
#              ('agile', 1),
#              ('onlookers', 52),
#              ('closely', 5),
#              ('smooth', 6),
#              ('stacking', 1),
#              ('against', 201),
#              ('backdrop', 9),
#              ('shoes', 91),
#              ('rappeling', 1),
#              ('headlamp', 2),
#              ('attached', 53),
#              ('snakeskin', 1),
#              ('sprays', 11),
#              ('frog', 5),
#              ('public', 48),
#              ('wood', 73),
#              ('barrior', 1),
#              ('animal', 99),
#              ('bird', 194),
#              ('seeds', 6),
#              ('sunflower', 1),
#              ('clinging', 5),
#              ('finger', 36),
#              ('wades', 12),
#              ('guided', 3),
#              ('laughs', 33),
#              ('playful', 7),
#              ('beige', 55),
#              ('torwards', 1),
#              ('outdoor', 137),
#              ('handstand', 48),
#              ('does', 232),
#              ('sheets', 5),
#              ('upside', 109),
#              ('snowboard', 88),
#              ('surfboard', 146),
#              ('bikes', 87),
#              ('traveling', 16),
#              ('worn', 5),
#              ('motorcycles', 27),
#              ('motorbikes', 7),
#              ('follow', 14),
#              ('garment', 2),
#              ('flag', 98),
#              ('crescent', 1),
#              ('moon', 5),
#              ('star', 13),
#              ('gown', 9),
#              ('muslim', 3),
#              ('helps', 29),
#              ('wave', 317),
#              ('half', 42),
#              ('naked', 52),
#              ('chair', 133),
#              ('older', 226),
#              ('back', 387),
#              ('relaxes', 12),
#              ('adobe', 1),
#              ('where', 40),
#              ('bicycles', 55),
#              ('propped', 4),
#              ('cap', 195),
#              ('close', 55),
#              ('parked', 41),
#              ('relaxing', 15),
#              ('folding', 11),
#              ('topless', 21),
#              ('slippers', 2),
#              ('navy', 14),
#              ('reclining', 2),
#              ('hauling', 1),
#              ('retrieve', 9),
#              ('mouths', 40),
#              ('tug', 44),
#              ('chew', 16),
#              ('haired', 203),
#              ('bottled', 2),
#              ('drink', 108),
#              ('tilted', 4),
#              ('spiked', 4),
#              ('party', 56),
#              ('streets', 28),
#              ('they', 121),
#              ('women', 652),
#              ('parade', 70),
#              ('neck', 49),
#              ('vegetation', 4),
#              ('filled', 52),
#              ('bushes', 37),
#              ('creating', 8),
#              ('splash', 44),
#              ('seaweed', 11),
#              ('lav', 1),
#              ('swimmers', 13),
#              ('kelp', 1),
#              ('foreground', 40),
#              ('sandals', 21),
#              ('short', 75),
#              ('sleeved', 17),
#              ('pinstripe', 2),
#              ('snows', 4),
#              ('furry', 59),
#              ('attempts', 56),
#              ('itself', 20),
#              ('self', 6),
#              ('backpacks', 32),
#              ('placed', 9),
#              ('cardboard', 27),
#              ('bus', 81),
#              ('station', 34),
#              ('bouncing', 29),
#              ('folded', 9),
#              ('beds', 3),
#              ('bedroom', 5),
#              ('snowboarder', 238),
#              ('slope', 76),
#              ('boarders', 1),
#              ('snowboarders', 12),
#              ('slopes', 7),
#              ('clothing', 130),
#              ('store', 111),
#              ('opening', 13),
#              ('stores', 8),
#              ('piece', 66),
#              ('attire', 25),
#              ('car', 429),
#              ('strip', 22),
#              ('boots', 66),
#              ('stepping', 8),
#              ('van', 16),
#              ('wear', 49),
#              ('game', 368),
#              ('plants', 43),
#              ('crossing', 58),
#              ('greenery', 6),
#              ('suspension', 1),
#              ('tropical', 12),
#              ('caution', 6),
#              ('sign', 245),
#              ('beside', 247),
#              ('bright', 124),
#              ('truck', 89),
#              ('others', 171),
#              ('helping', 27),
#              ('step', 30),
#              ('pulled', 39),
#              ('passengers', 8),
#              ('load', 2),
#              ('brightly', 38),
#              ('poses', 142),
#              ('pig', 5),
#              ('hugs', 24),
#              ('who', 216),
#              ('embracing', 8),
#              ('event', 66),
#              ('hugging', 59),
#              ('hooded', 36),
#              ('stretch', 11),
#              ('bicyclist', 64),
#              ('spandex', 3),
#              ('biking', 28),
#              ('jogging', 26),
#              ('headset', 5),
#              ('walkman', 1),
#              ('jogs', 13),
#              ('headphones', 42),
#              ('plant', 16),
#              ('corner', 59),
#              ('bicyclists', 24),
#              ('intersection', 14),
#              ('bikers', 31),
#              ('stop', 36),
#              ('town', 24),
#              ('without', 28),
#              ('guiding', 5),
#              ('wagon', 28),
#              ('escorts', 1),
#              ('leading', 21),
#              ('drawn', 4),
#              ('shetland', 1),
#              ('hits', 49),
#              ...])

# %%
# Create a word count of your tokenizer to visulize the Top 30 occuring words after text processing
get_top_words_based_on_cnt(tokenizer.word_counts,30)
#your code here

# %%
# Find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %%
# Pad each vector to the max_length of the captions ^ store it to a vairable

def padding_train_sequences(train_seqs,max_length,padding_type):
  cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding=padding_type,maxlen=max_length)
  return cap_vector

# %%
padded_caption_vector = padding_train_sequences(train_seqs,max_length,'post')

print("The shape of Caption vector is :" + str(padded_caption_vector.shape))
# Out:
# The shape of Caption vector is :(40455, 39)

# %%
padded_caption_vector
# Out:
# array([[ 3,  2, 44, ...,  0,  0,  0],
#        [ 3,  2, 20, ...,  0,  0,  0],
#        [ 3,  2, 41, ...,  0,  0,  0],
#        ...,
#        [ 3,  2, 45, ...,  0,  0,  0],
#        [ 3,  2, 86, ...,  0,  0,  0],
#        [ 3,  2, 86, ...,  0,  0,  0]], dtype=int32)

# %% [markdown]
# ## Pre-processing the images
#
# 1.Resize them into the shape of (299, 299)
#
# 3.Normalize the image within the range of -1 to 1, such that it is in correct format for InceptionV3.

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
img1,img1_path = load_image("/content/drive/My Drive/ImageCaptioning/Images/225909073_25c3c33a29.jpg")
print("Shape after resize :", img1.shape)
plt.imshow(img1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Shape after resize : (299, 299, 3)

# %%
encode_train_set = sorted(set(all_img_vector))

feature_dict = {}

image_data_set = tf.data.Dataset.from_tensor_slices(encode_train_set)
image_data_set = image_data_set.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(32)

# %%
image_data_set
# Out:
# <BatchDataset shapes: ((None, 299, 299, 3), (None,)), types: (tf.float32, tf.string)>

# %% [markdown]
# ## Create the train & test data
# 1.Combine both images & captions to create the train & test dataset using tf.data.Dataset API. Create the train-test spliit using 80-20 ratio & random state = 42
#
# 2.Make sure you have done Shuffle and batch while building the dataset
#
# 3.The shape of each image in the dataset after building should be (batch_size, 299, 299, 3)
#
# 4.The shape of each caption in the dataset after building should be(batch_size, max_len)

# %%
#write your code here
image_train, image_test, caption_train, caption_test = train_test_split(all_img_vector,padded_caption_vector,test_size=0.2,random_state=42)

# %%
print("Training data for images: " + str(len(image_train)))
print("Testing data for images: " + str(len(image_test)))
print("Training data for Captions: " + str(len(caption_train)))
print("Testing data for Captions: " + str(len(caption_test)))
# Out:
# Training data for images: 32364
# Testing data for images: 8091
# Training data for Captions: 32364
# Testing data for Captions: 8091

# %%
def map_function(image_name,capt):
    image_tensor = feature_dict[image_name.decode('utf-8')]
    return image_tensor,capt

# %% [markdown]
# ## Load the pretrained Imagenet weights of Inception net V3
#
# 1.To save the memory(RAM) from getting exhausted, extract the features of thei mage using the last layer of pre-trained model. Including this as part of training will lead to higher computational time.
#
# 2.The shape of the output of this layer is 8x8x2048.
#
# 3.Use a function to extract the features of each image in the train & test dataset such that the shape of each image should be (batch_size, 8*8, 2048)

# %%
import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.optimizers import Adam, RMSprop
from keras.layers.wrappers import Bidirectional
from keras.layers.merge import add
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.applications.inception_v3 import preprocess_input
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,weights='imagenet')

new_input = image_model.input #write code here to get the input of the image_model
hidden_layer = image_model.layers[-1].output #write code here to get the output of the image_model

image_features_extract_model = keras.Model(new_input, hidden_layer) #build the final model using both input & output layer

# %%
# write your code to extract features from each image in the dataset
image_features_extract_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 3 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, None, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 8 5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 8 240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 8 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 4 9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 9 55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 4 144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 9 288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 4 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 9 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, None, None, 1 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 6 76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 9 82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 3 6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 6 192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 6 192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 9 288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 3 96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 9 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 3 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 6 192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 9 55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 4 144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 9 288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 4 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 9 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 6 76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 9 82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 6 192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 6 192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 9 288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 6 192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 6 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 9 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 6 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 6 192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 6 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 9 55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 4 144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 9 288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 4 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 9 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 6 76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 9 82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 6 18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 6 192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 6 192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 9 288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 6 192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 6 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 6 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 9 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 6 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 6 192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 6 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 9 55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 9 288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 9 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 9 82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 3 1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 9 288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 3 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 9 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 1 384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 1 114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 1 384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 1 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 1 114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 1 384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 1 384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 1 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 1 114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 1 114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 1 384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 1 384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 1 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 1 172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 1 172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 1 576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 1 576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 1 576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 1 576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 1 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 1 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 1 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 1 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 1 179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 1 480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 1 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 1 480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 1 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 1 179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 1 179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 1 480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 1 480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 1 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 1 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 1 215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 1 576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 1 576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 1 576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 1 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 1 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 1 480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 1 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 1 179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 1 480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 1 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 1 480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 1 480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 1 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 1 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 1 179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 1 480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 1 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 1 215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 1 576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 1 576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 1 576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 1 576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 1 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 1 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 1 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 1 576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 1 258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 1 576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 1 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 1 258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 1 576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 1 576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 1 258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 1 258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 1 576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 1 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 1 258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 1 147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 1 576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 1 576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 1 576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 1 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, None, None, 1 576         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 3 552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 1 331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 3 960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, None, None, 1 576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 3 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 1 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, None, None, 4 1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 4 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, None, None, 3 1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, None, None, 3 1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, None, None, 3 1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 3 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 3 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, None, None, 3 442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, None, None, 3 442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, None, None, 3 442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, None, None, 3 442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, None, None, 3 1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, None, None, 3 1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, None, None, 3 1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, None, None, 3 1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, None, None, 1 245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, None, None, 3 960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 3 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 3 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 3 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 3 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, None, None, 1 576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 3 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 7 0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 1 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, None, None, 4 1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 4 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, None, None, 3 1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, None, None, 3 1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, None, None, 3 1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 3 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 3 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, None, None, 3 442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, None, None, 3 442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, None, None, 3 442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, None, None, 3 442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, None, None, 3 1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, None, None, 3 1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, None, None, 3 1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, None, None, 3 1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, None, None, 1 393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, None, None, 3 960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 3 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 3 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 3 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 3 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, None, None, 1 576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 3 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 7 0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 1 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
from tqdm import tqdm
for image,path in tqdm(image_data_set):
    batch_features = image_features_extract_model(image)
    batch_features = tf.reshape(batch_features,(batch_features.shape[0], -1, batch_features.shape[3]))
    for batch_f, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        feature_dict[path_of_feature] =  batch_f.numpy()
# Out:
# 100%|██████████| 253/253 [00:52<00:00,  4.86it/s]

# %%
batch_f.shape
# Out:
# TensorShape([64, 2048])

# %%
BATCH_SIZE = 32
BUFFER_SIZE = 1000
def generate_dataset(images_data, captions_data):
    
    dataset = tf.data.Dataset.from_tensor_slices((images_data, captions_data))
    dataset = dataset.shuffle(BUFFER_SIZE)

    dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_function, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(BATCH_SIZE)


    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return dataset

# %%
train_dataset=generate_dataset(image_train,caption_train)
test_dataset=generate_dataset(image_test,caption_test)

# %%
sample_img_batch, sample_cap_batch = next(iter(train_dataset))
print(sample_img_batch.shape)  #(batch_size, 8*8, 2048)
print(sample_cap_batch.shape) #(batch_size,40)
# Out:
# (32, 64, 2048)
# (32, 39)

# %% [markdown]
# ## Model Building
# 1.Set the parameters
#
# 2.Build the Encoder, Attention model & Decoder

# %%
embedding_dim = 256 
units = 512
vocab_size = 5001 #top 5,000 words +1
train_num_steps = len(image_train) // BATCH_SIZE
test_num_steps = len(image_test) // BATCH_SIZE

# %% [markdown]
# ### Encoder

# %%
from tensorflow.keras import Input, layers

# %%
class Encoder(Model):
    def __init__(self,embed_dim):
        super(Encoder, self).__init__()
        #self.dense = #build your Dense layer with relu activation
        self.fc = layers.Dense(embed_dim)
        self.dropout = layers.Dropout(0.5)
        
    def call(self, features):
        #features =  # extract the features from the image shape: (batch, 8*8, embed_dim)
        features = self.fc(features)
        features = tf.nn.relu(features)
        return features

# %%
encoder=Encoder(embedding_dim)

# %% [markdown]
# ### Attention model

# %%
class Attention_model(Model):
    def __init__(self, units):
        super(Attention_model, self).__init__()
        self.W1 = layers.Dense(units)
        self.W2 = layers.Dense(units)
        self.V = layers.Dense(1)
        self.units=units

    def call(self, features, hidden):
        #features shape: (batch_size, 8*8, embedding_dim)
        # hidden shape: (batch_size, hidden_size)
        hidden_with_time_axis =  tf.expand_dims(hidden, 1)
        score = keras.activations.tanh(self.W1(features) + self.W2(hidden_with_time_axis))
        attention_weights =  keras.activations.softmax(self.V(score), axis=1)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)
        

        return context_vector, attention_weights

# %%
class RNN_Decoder(Model):
    def __init__(self, embedding_dim, units, vocab_size):

        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = layers.Embedding(vocab_size, embedding_dim)
        self.gru = layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
        
        self.fc1 = layers.Dense(self.units)
        self.fc2 = layers.Dense(vocab_size)

        self.attention = Attention_model(self.units)

    def call(self, x, features, hidden):
    # defining attention as a separate model
        context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
        output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
        x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
        x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
        x = self.fc2(x)

        return x, state, attention_weights

    def init_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %% [markdown]
# ### Decoder

# %%
from tensorflow.keras.layers import LSTM, Embedding, TimeDistributed, Dense, RepeatVector, Activation, Flatten, Reshape, concatenate, Dropout, BatchNormalization, Conv2D
from tensorflow.keras import Input, layers
from tensorflow.keras import optimizers

# %%
class Decoder(Model):
    def __init__(self, embed_dim, units, vocab_size):
        super(Decoder, self).__init__()
        self.units=units
        self.attention = Attention_model(self.units)
        self.embed = layers.Embedding(vocab_size, embed_dim,mask_zero=False)
        self.gru = tf.keras.layers.GRU(self.units,return_sequences=True,return_state=True,recurrent_initializer='glorot_uniform')
        self.d1 = layers.Dense(self.units)
        self.d2 = layers.Dense(vocab_size)   
        self.dropout = Dropout(0.5)

    def call(self,x,features, hidden):
        context_vector, attention_weights = self.attention(features, hidden)
        embed = self.dropout(self.embed(x)) #shape: (batch_size, 1, embedding_dim)
        mask = self.embed.compute_mask(x)
        embed =  tf.concat([tf.expand_dims(context_vector, 1), embed], axis=-1)
        output,state = self.gru(embed,mask=mask)
        output = self.d1(output)
        output = tf.reshape(output, (-1, output.shape[2])) # shape : (batch_size * max_length, hidden_size)
        output = self.d2(output) # shape : (batch_size * max_length, vocab_size)

        return output,state, attention_weights
    
    def init_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
decoder=Decoder(embedding_dim, units, vocab_size)

# %%
features=encoder(sample_img_batch)

hidden = decoder.init_state(batch_size=sample_cap_batch.shape[0])
dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * sample_cap_batch.shape[0], 1)

predictions, hidden_out, attention_weights= decoder(dec_input, features, hidden)
print('Feature shape from Encoder: {}'.format(features.shape)) #(batch, 8*8, embed_dim)
print('Predcitions shape from Decoder: {}'.format(predictions.shape)) #(batch,vocab_size)
print('Attention weights shape from Decoder: {}'.format(attention_weights.shape)) #(batch, 8*8, embed_dim)
# Out:
# Feature shape from Encoder: (32, 64, 256)
# Predcitions shape from Decoder: (32, 5001)
# Attention weights shape from Decoder: (32, 64, 1)

# %% [markdown]
# ## Model training & optimization
# 1.Set the optimizer & loss object
#
# 2.Create your checkpoint path
#
# 3.Create your training & testing step functions
#
# 4.Create your loss function for the test dataset

# %%
optimizer = keras.optimizers.Adam()
loss_object = keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_path = "Flickr8K/File3/"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0
  hidden = decoder.init_state(batch_size=target.shape[0])
  dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          predictions, hidden, _ = decoder(dec_input, features, hidden)
          loss += loss_function(target[:, i], predictions)
          dec_input = tf.expand_dims(target[:, i], 1)
        
  avg_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, trainable_variables)
  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, avg_loss

# %%
@tf.function
def test_step(img_tensor, target):
  loss = 0
  hidden = decoder.init_state(batch_size=target.shape[0])
  dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          predictions, hidden, _ = decoder(dec_input, features, hidden)
          loss += loss_function(target[:, i], predictions)
          dec_input = tf.expand_dims(target[:, i], 1)
        
  avg_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, trainable_variables)
  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, avg_loss

# %%
def test_loss_cal(test_dataset):
    
  total_loss = 0
  for (batch, (img_tensor, target)) in enumerate(test_dataset):
    batch_loss, t_loss = test_step(img_tensor, target)
    
    total_loss += t_loss
    avg_test_loss=total_loss/test_num_steps
  return avg_test_loss

# %%
import time

# %%
loss_plot = []
test_loss_plot = []
EPOCHS = 9

best_test_loss=100
for epoch in tqdm(range(0, EPOCHS)):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(train_dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss
        avg_train_loss=total_loss / train_num_steps
        
    loss_plot.append(avg_train_loss)    
    test_loss = test_loss_cal(test_dataset)
    test_loss_plot.append(test_loss)
    
    print ('For epoch: {}, the train loss is {:.3f}, & test loss is {:.3f}'.format(epoch+1,avg_train_loss,test_loss))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    
    if test_loss < best_test_loss:
        print('Test loss has been reduced from %.3f to %.3f' % (best_test_loss, test_loss))
        best_test_loss = test_loss
        ckpt_manager.save()
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# For epoch: 1, the train loss is 1.187, & test loss is 1.010
# Time taken for 1 epoch 248.41077971458435 sec
#
# Test loss has been reduced from 100.000 to 1.010
#  22%|██▏       | 2/9 [06:22<24:59, 214.28s/it]
# For epoch: 2, the train loss is 0.936, & test loss is 0.898
# Time taken for 1 epoch 133.92032051086426 sec
#
# Test loss has been reduced from 1.010 to 0.898
#  33%|███▎      | 3/9 [08:37<19:02, 190.35s/it]
# For epoch: 3, the train loss is 0.853, & test loss is 0.828
# Time taken for 1 epoch 134.3184027671814 sec
#
# Test loss has been reduced from 0.898 to 0.828
#  44%|████▍     | 4/9 [10:52<14:29, 173.84s/it]
# For epoch: 4, the train loss is 0.793, & test loss is 0.774
# Time taken for 1 epoch 135.16525864601135 sec
#
# Test loss has been reduced from 0.828 to 0.774
# For epoch: 5, the train loss is 0.744, & test loss is 0.727
# Time taken for 1 epoch 134.64910531044006 sec
#
# Test loss has been reduced from 0.774 to 0.727
#  56%|█████▌    | 5/9 [13:07<10:48, 162.15s/it]
# For epoch: 6, the train loss is 0.700, & test loss is 0.685
# Time taken for 1 epoch 134.80831575393677 sec
#
# Test loss has been reduced from 0.727 to 0.685
#  67%|██████▋   | 6/9 [15:22<07:42, 154.02s/it]
# For epoch: 7, the train loss is 0.661, & test loss is 0.647
# Time taken for 1 epoch 134.2486436367035 sec
#
# Test loss has been reduced from 0.685 to 0.647
#  78%|███████▊  | 7/9 [17:36<04:56, 148.15s/it]
# For epoch: 8, the train loss is 0.626, & test loss is 0.612
# Time taken for 1 epoch 134.8059046268463 sec
#
# Test loss has been reduced from 0.647 to 0.612
#  89%|████████▉ | 8/9 [19:51<02:24, 144.21s/it]
# For epoch: 9, the train loss is 0.592, & test loss is 0.581
# Time taken for 1 epoch 135.23598647117615 sec
#
# Test loss has been reduced from 0.612 to 0.581
# 100%|██████████| 9/9 [22:07<00:00, 147.50s/it]

# %%
plt.plot(loss_plot)
plt.plot(test_loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Model Evaluation
# 1.Define your evaluation function using greedy search
#
# 2.Define your evaluation function using beam search ( optional)
#
# 3.Test it on a sample data using BLEU score

# %% [markdown]
# ### Greedy Search

# %%
max_l = 39

# %%
def evaluate(image):
    max_length=max_l
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.init_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0) #process the input image to desired format before extracting features
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot,predictions

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot,predictions

# %% [markdown]
# ### Beam Search(optional)

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
def beam_evaluate(image, beam_index = 3):
    max_length=max_l
    start = [tokenizer.word_index['<start>']]
    result = [[start, 0.0]]

    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.init_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)

    while len(result[0][0]) < max_length:
        i=0
        temp = []
        for s in result:
            predictions, hidden, attention_weights = decoder(dec_input, features, hidden)
            attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()
            i=i+1
            word_preds = np.argsort(predictions[0])[-beam_index:]
          
            for w in word_preds:
                next_cap, prob = s[0][:], s[1]
                next_cap.append(w)
            
                prob += np.log(predictions[0][w])
                    
                temp.append([next_cap, prob])
        result = temp
        result = sorted(result, reverse=False, key=lambda l: l[1])
        result = result[-beam_index:]
        
        
        predicted_id = result[-1]
        pred_list = predicted_id[0]
        
        prd_id = pred_list[-1] 
        if(prd_id!=3):
            dec_input = tf.expand_dims([prd_id], 0)  
        else:
            break
    
    
    result2 = result[-1][0]
    
    intermediate_caption = [tokenizer.index_word[i] for i in result2]
    final_caption = []
    for i in intermediate_caption:
        if i != '<end>':
            final_caption.append(i)
            
        else:
            break

    attention_plot = attention_plot[:len(result), :]
    final_caption = ' '.join(final_caption[1:])
    return final_caption

# %%
def plot_attmap(caption, weights, image):

    fig = plt.figure(figsize=(10, 10))
    temp_img = np.array(Image.open(image))
    
    len_cap = len(caption)
    for cap in range(len_cap):
        weights_img = np.reshape(weights[cap], (8,8))
        weights_img = np.array(Image.fromarray(weights_img).resize((224, 224), Image.LANCZOS))
        
        ax = fig.add_subplot(len_cap//2, len_cap//2, cap+1)
        ax.set_title(caption[cap], fontsize=15)
        
        img=ax.imshow(temp_img)
        
        ax.imshow(weights_img, cmap='gist_heat', alpha=0.6,extent=img.get_extent())
        ax.axis('off')
    plt.subplots_adjust(hspace=0.2, wspace=0.2)
    plt.show()

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
def filt_text(text):
    filt=['<start>','<unk>','<end>'] 
    temp= text.split()
    [temp.remove(j) for k in filt for j in temp if k==j]
    text=' '.join(temp)
    return text

# %%
import numpy as np

# %%
features_shape = batch_f.shape[1]
attention_features_shape = batch_f.shape[0]

# %%
rid = np.random.randint(0, len(image_test))
test_image = image_test[rid]
#test_image = './images/413231421_43833a11f5.jpg'
#real_caption = '<start> black dog is digging in the snow <end>'

real_caption = ' '.join([tokenizer.index_word[i] for i in caption_test[rid] if i not in [0]])
result, attention_plot,pred_test = evaluate(test_image)


real_caption=filt_text(real_caption)      


pred_caption=' '.join(result).rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = pred_caption.split()

score = sentence_bleu(reference, candidate, weights=(0.5, 0.5, 0, 0))
print(f"BLEU score: {score*100}")

print('Real Caption:', real_caption)
print('Prediction Caption:', pred_caption)
plot_attmap(result, attention_plot, test_image)


Image.open(test_image)
# Out:
# BLEU score: 87.72279297934199
# Real Caption: a little child in a green shirt eats a crust of bread smiling
# Prediction Caption: a child in a green shirt eats a crust of bread smiling
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x500 at 0x7F2F1DCEBA58>

# %%
captions=beam_evaluate(test_image)
print(captions)
# Out:
# a little in face

# %% [markdown]
# ##Caption to Audio generation (Text to Speech) part

# %%
from gtts import gTTS
from IPython.display import Audio
tts = gTTS("Predicted Caption is: "+ pred_caption) 
tts.save('s.wav')
sound_file = 's.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
